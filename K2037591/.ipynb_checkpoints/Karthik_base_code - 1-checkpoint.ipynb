# %% [markdown]
# # **Sentiment Analysis of Tweets**

# %%
# # Importing Libraries
# !pip install neattext
# !pip install ktrain
# #==0.23.2
# !pip install imblearn
# !pip install emoji
import emoji
from sklearn.ensemble import RandomForestClassifier
from imblearn.metrics import sensitivity_score, specificity_score
import neattext.functions as nfx
from sklearn import metrics
from sklearn import svm
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np
import math
import ktrain
import numpy as np
import pandas as pd
from ktrain import text
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import os
from textblob import TextBlob
from wordcloud import WordCloud
from collections import Counter
import numpy as np
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import string
from sklearn.feature_extraction.text import CountVectorizer
import nltk
import tweepy
import sys
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import datetime 
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import pandas as pd
from nltk.corpus import stopwords
import re
pd.set_option('display.max_colwidth', 100)
import unicodedata
import plotly.graph_objects as go
import seaborn as sns
from nltk import bigrams
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
from plotly.subplots import make_subplots
from nltk.util import ngrams
import nltk

# Elements of preprocessing
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('vader_lexicon')
# Out:
# Requirement already satisfied: neattext in c:\programdata\anaconda3\envs\env\lib\site-packages (0.1.2)
# Requirement already satisfied: ktrain in c:\users\administrator\appdata\roaming\python\python37\site-packages (0.28.2)
# Requirement already satisfied: fastprogress>=0.1.21 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (1.0.0)
# Requirement already satisfied: langdetect in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (1.0.9)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (3.5.1)
# Requirement already satisfied: pandas>=1.0.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (1.3.5)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (2.26.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (21.3)
# Requirement already satisfied: cchardet in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (2.1.7)
# Requirement already satisfied: chardet in c:\users\administrator\appdata\roaming\python\python37\site-packages (from ktrain) (4.0.0)
# Requirement already satisfied: seqeval==0.0.19 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (0.0.19)
# Requirement already satisfied: keras-bert>=0.86.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (0.88.0)
# Requirement already satisfied: whoosh in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (2.7.4)
# Requirement already satisfied: syntok in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (1.3.2)
# Requirement already satisfied: transformers<=4.10.3,>=4.0.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (4.10.3)
# Requirement already satisfied: sentencepiece in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (0.1.96)
# Requirement already satisfied: scikit-learn==0.23.2 in c:\users\administrator\appdata\roaming\python\python37\site-packages (from ktrain) (0.23.2)
# Requirement already satisfied: jieba in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (0.42.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from scikit-learn==0.23.2->ktrain) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from scikit-learn==0.23.2->ktrain) (3.0.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\envs\env\lib\site-packages (from scikit-learn==0.23.2->ktrain) (1.18.5)
# Requirement already satisfied: Keras>=2.2.4 in c:\programdata\anaconda3\envs\env\lib\site-packages (from seqeval==0.0.19->ktrain) (2.7.0)
# Requirement already satisfied: keras-transformer>=0.39.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-bert>=0.86.0->ktrain) (0.39.0)
# Requirement already satisfied: keras-layer-normalization>=0.15.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain) (0.15.0)
# Requirement already satisfied: keras-multi-head>=0.28.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain) (0.28.0)
# Requirement already satisfied: keras-pos-embd>=0.12.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain) (0.12.0)
# Requirement already satisfied: keras-position-wise-feed-forward>=0.7.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain) (0.7.0)
# Requirement already satisfied: keras-embed-sim>=0.9.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain) (0.9.0)
# Requirement already satisfied: keras-self-attention>=0.50.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-multi-head>=0.28.0->keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain) (0.50.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain) (4.28.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\env\lib\site-packages (from pandas>=1.0.1->ktrain) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->ktrain) (1.16.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain) (3.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain) (4.62.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain) (6.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain) (4.8.2)
# Requirement already satisfied: sacremoses in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain) (0.0.46)
# Requirement already satisfied: huggingface-hub>=0.0.12 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain) (0.2.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain) (2021.8.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\envs\env\lib\site-packages (from huggingface-hub>=0.0.12->transformers<=4.10.3,>=4.0.0->ktrain) (3.10.0.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\env\lib\site-packages (from tqdm>=4.27->transformers<=4.10.3,>=4.0.0->ktrain) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\env\lib\site-packages (from importlib-metadata->transformers<=4.10.3,>=4.0.0->ktrain) (3.6.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\env\lib\site-packages (from requests->ktrain) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\env\lib\site-packages (from requests->ktrain) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from requests->ktrain) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from requests->ktrain) (1.26.7)
# Requirement already satisfied: click in c:\programdata\anaconda3\envs\env\lib\site-packages (from sacremoses->transformers<=4.10.3,>=4.0.0->ktrain) (8.0.3)
# Requirement already satisfied: imblearn in c:\programdata\anaconda3\envs\env\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\programdata\anaconda3\envs\env\lib\site-packages (from imblearn) (0.8.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\envs\env\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Collecting scikit-learn>=0.24
#   Using cached scikit_learn-1.0.2-cp37-cp37m-win_amd64.whl (7.1 MB)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\ProgramData\\Anaconda3\\envs\\env\\Lib\\site-packages\\sklearn\\_isotonic.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\envs\env\lib\site-packages (from imbalanced-learn->imblearn) (1.18.5)
# Requirement already satisfied: scipy>=0.19.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from imbalanced-learn->imblearn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (3.0.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
#   Rolling back uninstall of scikit-learn
#   Moving to c:\users\administrator\appdata\roaming\python\python37\site-packages\scikit_learn-0.23.2.dist-info\
#    from c:\users\administrator\appdata\roaming\python\python37\site-packages\~cikit_learn-0.23.2.dist-info
#   Moving to c:\users\administrator\appdata\roaming\python\python37\site-packages\sklearn\
#    from c:\users\administrator\appdata\roaming\python\python37\site-packages\~-learn
# Requirement already satisfied: emoji in c:\programdata\anaconda3\envs\env\lib\site-packages (1.6.1)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp\2/ipykernel_5576/1095642829.py in <module>
#      33 from sklearn.feature_extraction.text import CountVectorizer
#      34 import nltk
# ---> 35 import tweepy
#      36 import sys
#      37 from tweepy import Stream
#
# ModuleNotFoundError: No module named 'tweepy'

# %% [markdown]
# - Uncomment the line below in order to fetch the tweets from twitter and save in csv format on the needed location.

# %%
import tweepy
import pandas as pd
#Twitter developer account credentials
consumer_key="ArvY8sU6HDZSuGk9nMADCd1Za"
consumer_secret="WhhxixavlxGgAsr6nHwwjmsEDdNCBGCC2LxHJWLl0Tho5OcTKe"
access_token="2415738176-GCKuN5W25sftYfjOMXMgA1UXaS6kHkl8gYnMWGm"
access_token_secret="GBzgC4NrDA4XhCf7CS6md1zQuNmm0o458rhJSqfz3PFki"
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAB%2FTNwEAAAAAVJ9eZ2QOZtV6XLvnSyKpFLXsSvM%3DxZ6H7C5dNsJTvzttvypgHnedYpByZ9bUOgvxQXXLVHf2TdAEFU"

#Switching to application authentication
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_token_secret)
auth.secure = True

#Setting up api wrapper
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

#Error handling
if (not api):
    print ("Problem in connecting to API")

#You can check how many queries you have left using rate_limit_status() method
api.rate_limit_status()['resources']['search']

# Switching to application authentication
auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)

# Setting up new api wrapper, using authentication only
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# Handels error if any
if (not api):
    print ("Problem in Connecting to API")

#maximum number of tweets
number_tweets= 1000
#Per query tweets
tweetsPerQry = 100

#search_words
search_words= "india"

retweet_filter='-filter:retweets'

q=search_words+retweet_filter
# Specify the date
date_since= "2020-12-08"

tweetCount = 0
geo =[]
tweets=[]
likes=[]
user=[]
location= []
date=[]


for tweet in tweepy.Cursor(api.search, q= q,lang="en",since= date_since, tweet_mode='extended').items(number_tweets) :
        geo.append(tweet.geo)
        tweets.append(tweet.full_text)
        likes.append(tweet.favorite_count)
        user.append(tweet.user.screen_name)
        location.append(tweet.user.location)
        date.append(tweet.created_at)
        tweetCount += 1

print("Downloaded {0} tweets".format(tweetCount))

vacc_tweet_5= pd.DataFrame({'geo':geo,'tweets':tweets,'likes':likes,'user':user,'location':location,'date': date})

#Saving Tweets in csv file
vacc_tweet_5.to_csv('/content/drive/MyDrive/Kartik/vaccination_all_tweets.csv',index=False)

# %%
# Loading dataset with encoding type
# df1 data is generated with the help of the above code
import pandas as pd
df1 = pd.read_csv('./covid_vaccine.csv' ,encoding= 'unicode_escape')
# df2 data is generated with the help of scrape.ipynb file from the twitter
df2 = pd.read_csv('./complete_covid_tweets.csv')
# Out:
# C:\ProgramData\Anaconda3\envs\env\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Data1
df1.head()
# Out:
#        tweet_id  label                                         tweet_text
# 0  1.360342e+18      1  4,000 a day dying from the so called Covid-19 ...
# 1  1.382896e+18      2  Pranam message for today manifested in Dhyan b...
# 2  1.375673e+18      2  Hyderabad-based ?@BharatBiotech? has sought fu...
# 3  1.381311e+18      1  Confirmation that Chinese #vaccines "dont hav...
# 4  1.362166e+18      3  Lab studies suggest #Pfizer, #Moderna vaccines...

# %%
# Data2
df2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1         username  \
# 0           0           0.0  forbesmarketing
# 1           1           1.0  citizenofthewr1
# 2           2           2.0      GRamsbottom
# 3           3           3.0   ArthurReinholt
# 4           4           4.0   africanaffairs
#
#                                          description  \
# 0                                                NaN
# 1  Interested in world politics. Advocate for pea...
# 2  1st Lady of HR- 🇨🇦; owner of 3 lovely blockcha...
# 3                                                NaN
# 4  All about #AfricanAffairs. Promoting African H...
#
#                          location  following  followers  totaltweets  \
# 0                             NaN      286.0       27.0       4966.0
# 1                             NaN      580.0       21.0       5297.0
# 2  Oxford U; Harvard U; McGill U      2620.0     1791.0     113417.0
# 3                    Indiana, USA      334.0       90.0       2138.0
# 4                          Africa      974.0     1095.0      37974.0
#
#    retweetcount                                               text  \
# 0           4.0  United Airlines have updated their coronavirus...
# 1         153.0  Inside an Ontario ICU where the COVID-19 patie...
# 2           0.0  #recruitment changes in the post #coronavirus ...
# 3        3704.0  🇺🇸🦠 A sea of 650,000 white flags - one for eve...
# 4           0.0  Now playing on African Affairs Radio: mawie by...
#
#                                             hashtags  tweet_id  label  \
# 0                                                 []       NaN    NaN
# 1                                                 []       NaN    NaN
# 2  ['recruitment', 'coronavirus', 'HR', 'RH', 'te...       NaN    NaN
# 3                                                 []       NaN    NaN
# 4  ['africansarenotlabrats', 'standby', 'coronavi...       NaN    NaN
#
#   tweet_text
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# Taking the relevant column
df2 = df2[['text']]
df2.head()
# Out:
#                                                 text
# 0  United Airlines have updated their coronavirus...
# 1  Inside an Ontario ICU where the COVID-19 patie...
# 2  #recruitment changes in the post #coronavirus ...
# 3  🇺🇸🦠 A sea of 650,000 white flags - one for eve...
# 4  Now playing on African Affairs Radio: mawie by...

# %%
# creating dataframe
df = pd.DataFrame(columns=['text'])
df.text = df1['tweet_text']

# combining the data
df = df.append(df2)
df.head()
# Out:
#                                                 text
# 0  4,000 a day dying from the so called Covid-19 ...
# 1  Pranam message for today manifested in Dhyan b...
# 2  Hyderabad-based ?@BharatBiotech? has sought fu...
# 3  Confirmation that Chinese #vaccines "dont hav...
# 4  Lab studies suggest #Pfizer, #Moderna vaccines...

# %%
# Checking the shape
df.shape
# Out:
# (90180, 1)

# %%
# Columns in the data
df.columns
# Out:
# Index(['text'], dtype='object')

# %%
# Checking the null values
df.isnull().sum()
# Out:
# text    6000
# dtype: int64

# %%
# Dropping out null values from the dataset
df.dropna(inplace=True)

# Combining the data and then saving the relevant portion so as to use it directly
# df.to_csv('kartik_data.csv')

# %%
# Loading the data
df=pd.read_csv('./kartik_data.csv')
df.drop(df.columns[0], axis=1, inplace=True)
df.head()
# Out:
#                                                 text
# 0  4,000 a day dying from the so called Covid-19 ...
# 1  Pranam message for today manifested in Dhyan b...
# 2  Hyderabad-based ?@BharatBiotech? has sought fu...
# 3  Confirmation that Chinese #vaccines "dont hav...
# 4  Lab studies suggest #Pfizer, #Moderna vaccines...

# %%
# Shape
df.shape
# Out:
# (84180, 1)

# %% [markdown]
# - Removing all the emojis instances because a tweet can have different contexts, there is a huge possibility that the replacing word of emoji might take the sentence in totally different possibilty which will lead our model to predict wrong.

# %%
# tweet removal
def extract_emojis(s):
  return ''.join(c for c in s if c in emoji.UNICODE_EMOJI['en'])

data = []
for i in range(df.shape[0]):
  emoji_ = []
  emoji_ = extract_emojis(df.text[i])
  if len(emoji_)==0:
      data.append(df.text[i])

# %%
# Length
len(data)
# Out:
# 74746

# %% [markdown]
# - Removing the tweets which are having urls with them. It is because when a post is created then there is a possibility that tweet might be absent another possibilty is the only presence of hashtags therefore removing those tweets is the better opinion to achieve better accuracy.

# %%
#removing tweets containing urls
data_noUrl = []
for tweet in data:
  if 'https:' not in tweet:
    data_noUrl.append(tweet)
len(data_noUrl)
# Out:
# 23898

# %%
# Sample
data_noUrl[3]
# Out:
# 'When we can get #moderna and #pfitzer Vaccine in India?\n@narendramodi \n@MoHFW_INDIA'

# %%
#removing some escape characters
escapes = '\b\n\x92\x91\x93\x94\r\t\\' 
for s in range(len(data_noUrl)):
  for c in escapes: 
    data_noUrl[s]=data_noUrl[s].replace(c, '') 
data_noUrl
# Out:
# ['Safe and effective. #OxfordAstraZeneca',
#  'The day after the #Moderna #COVID19Vaccine... My arm is a little sore and I am a little more fatigued than usual. My grandparents had no noticeable effects though.',
#  '@syd_m39 Not a girl but part of the #Moderna club ?',
#  'When we can get #moderna and #pfitzer Vaccine in India?@narendramodi @MoHFW_INDIA',
#  'Officially a #Moderna gay ?',
#  'Got the #PfizerBioNTech vaccine !!',
#  '@sanket #SputnikV  at 91% efficiency is far ahead of #Covishield and #Covaxin.',
#  'One more to go #firstdosedone #Moderna thankful @SutterHealth @SCCgov',
#  'I got the second dose of my #Moderna #vaccine yesterday and so far the only side effect has been (pretty bad but manageable) soreness in the injected arm.',
#  'Just got  my 2nd #moderna shot. My mom &amp; grandma got #johnsonandjohnson &amp; #pfizer. We 3 have deathly allergies, but had zero #allergic or adverse reactions ! Dont let allergies stop you from getting the #COVID19Vaccine',
#  'Especially because we lack data on #johnsonandjohnson vaccine efficacy specifically against the #B117 variant which is fueling the current surge. There is precedent to granting EUA before final data from phase 3 is available as in #SputnikV and #Covaxin. @aslavitt46 @US_FDA',
#  'Got my first dose of the Moderna vaccine. Im not sure its working - Jeff Bezos hasnt sent in my check. Is this thing on?? #sarcasm #getvaccinated #moderna #COVID19Vaccine',
#  '@catcheronthesly Let us change the goal post. So now this is between you and me and not related to CONG or MMSYes, like COVAXIN, they should have given emergency approval to #SputnikV and maybe others and should have allowed people to pay and get #vaccinated with #vaccine of their choice',
#  "#SputnikV gets approval within 2 days of @RahulGandhi's suggestion of fast tracking approval of other vaccines as per norms!After mocking @RahulGandhi, Modi govt does exactly what he suggested.Resignation Prasad should apologise and resign now!",
#  'Just got my first vaccine!! #Moderna Mahalo to @HawaiiDOH for running such a smooth clinic in Kona! #CovidVaccine',
#  'Starting today, a new chapter begins at my hospital @MaimonidesMC filled with hopes to end dark COVID times &amp; joy of celebrating life.#CovidVaccine #PfizerBioNTech #mrnavaccine #COVIDends',
#  'Researchers said the risk of cerebral venous thrombosis from the #Covid was approximately:?10 times higher compared to messenger RNA vaccines.?8 times higher compared to the #oxfordastrazeneca vaccine',
#  'This guy just got his first dose of the Moderna vaccine today! I am now halfway closer to getting back to Lawrence! #moderna #SleeveUpJoCo',
#  '@LINDAINLIGHT @normanswan #AstraZenica has substantially lower efficacy than #Pfizer or #Moderna While blood clot deaths are rare, there have been some across all age groups vaccinated, including those aged 55+',
#  'The AstraZeneca vaccine causing blood clots?! What such nonsense! ? My mother had her shot of it two weeks ago and only got a headache and fatigue after it, and is now right as rein! ? #CovidVaccine #oxfordastrazeneca',
#  "Modi Government go ahead in production of #Covaxin to #Maharashtra Govt It's #BharatBiotech vaccine now said company too can produce but this also will take time",
#  "...and in other news, just got my first dose of the Modern COVID-19 vaccination. Tiny needle, didn't feel a thing, and I'm feeling absolutely fine afterwards.Take *that*, you evil little bastard.#Moderna #COVID19Vaccine",
#  'The govt was pushed to corner to ban the Russian #SputnikV vaccine in KE &amp; only accept the UK #AstraZenaca little did they know the master will issue threats against KE. We should allow all vaccines to be sold in KE &amp; end the colonial monopoly of UK. #KenyaVsUK Nanyuki Kibaki',
#  'FWIW: Ill go with the 2- shots of either #Pfizer or #Moderna. J&amp;J isnt as effective with one shot. Better efficacy is worth having to go through two rounds of shots. #COVID19Vaccine',
#  'Got my first Moderna shot yesterday! Ask me how it went! #moderna #vaccine',
#  'Pakistan is using #Sinopharm . This is the processAfter 1st dose, person has to wait for 21 days to get 2nd dose. After 2nd dose, wait 14 days for vaccine to make antibodiesPERSON CAN GET #COVID  EVEN AFTER VACCINATION. VACCINATION DOES NOT MEAN  YOU WILL  NOT GET #coronavirus',
#  '@GuidoFawkes perhaps a trial run for the new Ranger Regt, Tier 2, to recover about 15 million doses of #OxfordAstraZeneca ?',
#  '@OmarChughtai any update on Sputnik?#coronavirus #CoronavirusVaccine #SputnikV',
#  'Two days and a few Tylenol later I am feeling much better today.  #Moderna',
#  'Just got my first dose of the #Moderna vaccine!',
#  "India's defense budget is 100 billion $ while Pakistan's budget is 11 billion $. If your enemy is stronger than you, you will teach children that weapons and missiles are useless. Let's kill the enemy with a slingshot?Think wisely. Everything will happen if you exist.#Sinopharm",
#  'i am now a 5G Enabled bobcatbeep boop#PfizerBioNTech',
#  '@FinancialTimes not so sure b/c ... ?...DARPA funding development of implantable biochip...The chip is able to deploy experimental new #vaccine , developed jointly by #Moderna and U.S govt, that could change human DNA ?able to reprogram\xa0mRNA aka messenger ribonucleic acid strange ?',
#  "@Koachkelly68 @parkrunUK Same here. Had mine this morning with the #OxfordAstraZeneca jab. Apart from a very slightly sore arm, I'm feeling fine.",
#  '@MayoClinic I was sick for days after 2nd shot of #Moderna shot. Fever body aches headaches ? whole body sore?',
#  "My mom finally got her 2nd dose of #Sinopharm vaccine. Her vaccination process is complete. She'll quarantine for another 2 weeks to develop life-time antibodies. No side effects so far! Get yourself vaccinated! Follow #SOPs Thank you #China #CovidVaccine #Covid_19 #Pakistan",
#  'Buckle up buttercup, the second #PfizerBioNTech dose is a bear! My misgivings about very mild side effects with the first dose have now been alleviated! Sure beats the real thing, though... #COVID19 @VUMChealth',
#  '@pakned43 @BBhuttoZardari He is in the opposition and raise the issue! His voice is heard, for a sindh they are also importing #SputnikV and Chinese vaccine which will be given free. If you have a better idea plz speak.',
#  '@DixieBootsnwine Their plan all along #Gates #Eugenics#WorldEconomicForum #KlausSchwab #CDC #NIH #NIAID #Fauci #BigPharma #Moderna #COVID19 #COVID?19 #COVID19Vaccine',
#  '#Covaxin Generally medicine used to cure illness, first time its being used to get vote, no names here',
#  '#BREAKINGBIG VACCINE UPDATEAfter approving #SputnikV,  more foreign vaccines are lively to be given emergency use authorization in India.Govt is looking to expand basket of vaccines in order to ramp up the #VaccinationDrive(1/n)#vaccineshortage #VaccinateEveryIndian',
#  'Ok, so feeling the arm soreness today but not too bad.  Still feel more tired than normal and dealing with nasal issues but just think thats due to allergies more than anything.  So all in all not too awful but noticeable.  Hoping the second one is easier. #moderna',
#  '@TheLancet article hugely boosted #SputnikV @sputnikvaccine vaccine image in the EU. We are already witnessing a race not only to procure it when approved by EMA but to produce it as well. #Germany #Austria #Slovakia all have shown interest in domestically producing it. #Russia',
#  "Got my second #Moderna vaccine yesterday.  Feeling like I got run over by a truck today. ?? However, I'm so #grateful! #worthit #fullyvaccinated #thankful",
#  'Ok, if you got sick after your second injection, when did it happen? #Moderna #phizer #JabToBeatCorona #vaccine',
#  'Got my first dose of the #PfizerBioNTech #COVID19 #CoronavirusVaccine yesterday ? Side effects over the last 24 hours have been slightly achy arm. Antibody test the day before showed I had zero anti-SARS2-COV antibodies. Lets see how many I have in a few weeks...',
#  'Dr. Daniel Chirundu said took the #Sinopharm vaccine to protect himself, those he works with, and his clients. His vaccination also served as a cue to action among my subordinates and others who are now demanding it.',
#  'Having slept for pretty much two days, after my #CovidVaccine.  I thought Id re-sync my body clock, by staying up all night, with all 4 hours of #ZackSnydersJusticeLeague, but after seeing a trailer for #RiverHunters, Ive just watched the entire first series! #OxfordAstraZeneca',
#  '@paulie_paulie It was a British jab for British people :-)#oxfordastrazeneca (Okay its made in Belgium, but it says Oxford in the title dammit!!)',
#  'As a pregnant person who is getting the #Moderna  #CovidVaccine today, does anyone know if there are any official studies I can enter myself into? #COVID19 #Covid #coronavirus #CoronaVaccine @moderna_tx',
#  'Getting the #Moderna vax today! Worried about side effects but more excited to do my part to stop the damn spread. I had #COVID?19 in January and I do not recommend.',
#  '@ndtv Despite highest recovery rate than rest of world and Vaccines #Covishield #COVAXIN  invented and administerd on war footing with much fanfare, the situation is still  alarming,means Vaccines are not efficacious to contain #coronavirus and it was all drama to pacify the outcry.',
#  'Had my 2nd #moderna shot yesterday. I am off today and in anticipation of having possible negative side effects decided sending K to daycare was a good idea. DH has made me feel so guilty for being off and sending him. I dont know that he means to but ugh. Im going back to bed.',
#  "#Bahrain's Ministry of Health receives 300,000 doses of the Chinese #COVID-19 #Sinopharm vaccine",
#  '(Jakarta 13/4) Siti Nadia Tarmizi, a spokesperson for Indonesias COVID-19 vaccine programme, said WHO had found the Chinese vaccines had met requirements by being more than 50% effective. She noted that clinical trials for the #Sinovac in Indonesia showed it was 65% effective.',
#  '#SpeakUpForVaccinesForAll People who want #Covaxin , can demand at Amitshah and Modi rally.?? #coronavirus #COVID19',
#  '@stalinsachin @ADeshbakth Every time I read such stories I\'m tempted to ask, "Vote kisko diya tha ?". I know it\'s mean. Okay no, very mean. But in #NewIndia, it\'s a pertinent question, IMO #COVID #COVID19 #Covaxin',
#  '@toryboypierce @pfizer Actually what the French have done is acknowledge their vaccine wouldnt be ready until the end of 2021 and have turned their facilities over to the production of the #PfizerBioNTech vaccine.',
#  'Despite #india at the brink of a  more severe second wave, will not even consider #CovidVaccine as none are trustworthy yet. Would have definitely taken had there been one genuine. #ChinaVirus #ChineseVirus #ChineseBioterrorism #CCPVirus #Covaxin #COVIDSHIELD',
#  'I bet the scientists who created all these vaccines are males who forgot that almost all women have breasts (armpit lymph nodes), ovaries and uterus (birth control and periods)! Not a single thought about women! Pathetic! Wake up gentlemen! ? #JohnsonandJohnson #Pfizer #Moderna',
#  'First dose of the Moderna COVID vaccine done. Feel fine so far. #Moderna #CovidVaccine #COVID',
#  'Going for #Moderna #2 today...#COVID19Vaccine#FastenSeatbelts#RaiseSeatsToUprightPosition#StoreTrayTables',
#  "@HuffPostUKPol Where's #SputnikV?? It has over 92% #SuccessRate than #Pfizer and has 0 DEATHS!!",
#  'Second dose of #moderna is kicking my ass.  Arm hurts like hell, fever, sweats, headache, teeth pain, and nausea.  This is not fun.  #COVID19Vaccination',
#  'First #COVID19 vaccine done ??. Sore but hopeful for summer fellowship and family hugs. #Moderna',
#  '@RShivshankar Along with #covaxin lets give a try to age-old Ayurvedic miracle drug honey as well.',
#  'Received 2nd dose of #Moderna #armissore Celebrated E (18 years)and dad (88 years)tonight while watching the Big 12 Tournament. Three months of #Journeyat55',
#  'What is the accepted price in lives to be loyal to the self-imposed rules of the EU? 1000 dead? 10 000 deaths ?? Most governments in the EU are more loyal to the EU than their own people. The solution is simple. Use Sputnik V and save lives. #SputnikV',
#  'Mostly #Sinovac inactivated #covidvaccine + only alum as adjuvant (+against original strain)....good luck relying on this to get you out of crisis.',
#  'Just got the vaccine! Thank you to science and everyone who had a hand in this!!!! #Moderna #vaccinated @moderna_tx',
#  'Why did sister P Niveda feel like a film celebrity as she administered the vaccine to the PM? Because Jab We Met #Covaxin #lamejoke',
#  'barely kept a cool head this morning with $OCGN when i saw 9$ on the ticker but kept cool and stayed calm, +28% and +240$ later here we are! #Covaxin got approved and once the US adopts it to get out vaccines faster this stock will have no limit, $CLSN could see similar movement',
#  'Symptoms update - Head feels a bit off. Arm feels heavy but not aching yet. (19:00) #oxfordastrazeneca #vaccine',
#  "@anupsoans #SputnikV got clearance today but when to you think it'll be available for #Vaccination?@drreddys",
#  "Bharat Biotech's vindication is heartening #Covaxin #BharatBiotech",
#  'Side effects so far 6 hours in: sore arm, slight headache, moodiness... oh woopsie I think the moody part is a lady problems side effect. ? #vaccination #moderna #womenproblems',
#  'Should the vaccination drive be open to all now?#COVID19 #CovidVaccine #COVID19Vaccination #Covaxin',
#  '@chennaicorp can we know the centers which provides #Covaxin in chennai?',
#  "To people who think that the side effects from the #Moderna vaccine will be bad, They were not for me. It is important to get COVID19 out of the picture. Get Vaccinated when it's YOUR TURN!",
#  '@ndtv Now where is our vaccine? Why corona is spreading again? Where is that vaccine which Modi ji took himself? Was that fake? Was that only to make us fools? #Covaxin #CovidVaccine #vaccine #coronavirus #Covid_19 #CoronaVirusUpdates #StaySafe',
#  'somewhere, someones gonna name their baby #moderna arent they',
#  "@ChuckGrassley Agreed, Charles!So...(?)Do something! Be BOLD!Normalize relations w #Russia:\x97 Release Economic Sanctions\x97 Re-establish Bilateral Cooperation\x97 Two Super Powers can stop #Covid19!#SputnikV works:\x97 YOU fear it; &amp;,\x97 It destroys #Covid19IN #Iowa, 7th Gen;I'M NOT afraid!",
#  'Hello my dear FINTWIT family, I got my Covid19 Vaccine first dose today. ? #Moderna Who all are invested in $MRNA ? ?',
#  'Covid-19 shot #2 in the books! #Moderna #vaccine',
#  'Flu like symptoms with a sore arm are fun #Moderna',
#  'Ive been waiting for the side effects of the #SecondDose of #Moderna to kick in.Im no longer waiting.  I feel like I got hit by a train.',
#  "@Shehzad89 Vaccines are free in #India at Govt Hospitals.. And it's capped to a maximum of INR 250 at Private Hospitals.. But the vaccines are #Covishield &amp; #Covaxin.. #Sputnik is not yet approved here.. Will get approval shortly.. It's going to get manufacture locally by 5 Pharma Firms..",
#  'Do pharmaceutical companies had victims from #covid19? #PfizerBioNTech #AstraZeneca #Moderna #COVID?19 #COVID20 #Covid',
#  "@ItalyUN_NY If Russia is in need to start production of  #SputnikV in Europe why don't we link permission to better relations with Ukraine (and #Navalny)? It worked with Soviet Union (#Jews,dissidents etc)",
#  "Getting my first shot of #CovidVaccine on Friday, #Moderna I believe.  I hope it doesn't hurt. ???",
#  'Vaccinated #Moderna ????',
#  'Got the #Moderna vaccine yesterday. Heres hows its been:T+1hr: Arm slightly sore. Felt great all day, better mood than usual.T+12hr: Felt tired. Arm hurt more. Generally fatigued. Slight ache in joints. Fell asleep fine. T+24hr: Woke up feeling fine. Arm hurt more.',
#  "#China's #Sinovac Biotech says it has doubled its annual #vaccine capacity to 2 billion doses. #Covid_19",
#  '@BDUTT @drriteshmalik What a waste of #Covaxin ?',
#  'Export our own vaccines, then import for shortfall of our needs. This must be the spirit of Aatmanirbhar Bharat. (Reliant India) #SputnikV #COVIDIOTS',
#  "Got my first @moderna_tx  shot yesterday.  Almost 24 hours later and I feel fine except for a sore arm.  Next one's in mid-April.  #COVID19Vaccine #slowthespread #Moderna #VaccinesSaveLives",
#  '@Swamy39 @Sanjaypro And #covaxin could not see the light of the day (#atmanirbhar) bcos of ppl lk u',
#  '@ProfMakris #SputnikV  uses two recombinant adenovirus types (rAd26 and rAd5).Why is it, that there are very view reports (if any) about vaccine induced Thrombosis with Thrombocytopenia? Strange.@sputnikvaccine',
#  'Czechs the latest (after Hungary et al) to accept Sputnik vaccine before EU approval. The latters vaccine incompetence exacerbating Russian threat, Eastern European countries already intimidated by increased political, military, cyber etc. threat from Moscow. #covid19 #SputnikV',
#  'Anyone else feel like they were hit by a Mack truck after dose 1? #Moderna',
#  'Very #grateful that @AllinaHealth in @cottagegrovemn had #CovidVaccine appointments open up this morning for shot number one today!  One down, one to go. #Moderna',
#  'Folks who had a real helluva time with side effects after their FIRST #Moderna dose and have already gotten their second, did you have',
#  'Secondly a massive thankYOU to the researchers who have worked tirelessly to advance our knowledge of #COVID19 in a breadth of different areas. Special shout out to all those involved in developing the #COVID19 vaccinations. #oxfordvaccine #PfizerBioNTech',
#  'So I just got my 2nd dose of #COVIDVaccination #moderna',
#  'Moderna Vaccine #1 update:Feeling fine with the exception of my extremely sore left arm where the shot was administered. So far so good. #Moderna #Covid19 #vaccination',
#  '#CovidVaccine Just days ago, South African scientists found that the #OxfordAstrazeneca vaccine wasnt considerably effective against the variant strain, 501Y.V2. This has now become the dominant strain circulating country-wide. #CoronavirusSA @etvNewsSA',
#  'Second dose done .. #Sinopharm',
#  '@politicalnative Nope!Same as the 1st. Tired &amp; a sore arm.Sooooooo worth it.Thanks, @POTUS @JoeBiden! ?????????#FauciOuchie #Moderna #vaccinated',
#  "Anyone had the second dose of #Moderna #COVID19Vaccination? I'm curious if the side effects are different from Pfizer? Getting my second shot Sunday.",
#  'Subject Same, Object SameOnly helping verb is added #lockdown2021#COVID19India#Covaxin',
#  'lol, the Europeans are finally going for #SputnikV',
#  'There is a massive elephant in the room today. Nothing mentioned about further supplies of #CoronavirusVaccine Have additional supplies of #PfizerBioNTech vaccine reached these shores yet? #TW2',
#  'Are we all in agreement that:#Moderna = #TeamValor#Pfizer  = #TeamMystic and#JohnsonAndJohnson = #TeamInstinct',
#  '#COVAXIN is more effective than #Covishield in my opinion!',
#  'Just got my 2nd vaccine! #moderna #vaccinated #VaccinateFightCorona #VETERAN',
#  '@olyatanas Really hoping for #SputnikV getting emergency authorization soon in India.  The more the merrier !',
#  '@sputnikvaccine @iDNEScz #SputnikV #STFBrasil #BolsonaroTemRazao   Brazilian Supreme Court and Communists are trying to destroy the President who is stopping corruption! please help !! Help -Ex president ordered the killing of Jair Bolsonaro #AdelioBispo Stab, millions of dead',
#  'So so Happy to receive the Moderna Covid-19 Vaccine today in Milan, ILLinois!! I come back in 28 days for my Booster! #CovidVax #CovidVaccine #Moderna #VaccinesWork #ScienceRocks',
#  'Brother, friend, and I all got our second round of #Moderna today. 12 hours later, brother has a migraine, friend has a migraine + chills, and my entire body aches. Gonna be a long night',
#  '48 hours post Astra/Oxford vax. All aches and pains gone. Left with sore throat, swollen arm and heavy fatigue. Hoping the fatigue is not the new normal! #Long Covid #OxfordAstraZeneca',
#  '@PMOIndia @rssurjewala @IMAIndiaOrg Instead of forcing manufacturers to put other vaccine use under list of Contraindications, Government should start using Covaxin on HCW already vaccinated with covishield to protect them from Mutant strains#Covaxin #Covishield #COVID19',
#  '#Vaccine #CDC #FAUCI #WHO #Moderna #Pfizer #JohnsonAndJohnsonVaccine  The vaccine is experiential. Only complete dipshits will blindly trust big pharma.. the same people killed mothers, sisters and daughters with their baby powders and then lied about it.',
#  '@nuclearleb @JilekLukas @sputnikvaccine Do you think Germany will use #sputnikv without a quality control, which #slovakia started and was accused of sabotage by #RDIF ? keep dreaming :Di can`t wait for tests performed on this rubbish by german labs. I can already hear #RDIF screaming "sabotage" and "fake news" :D',
#  "@A2606Sneha @RetweetsPune @coincidentaldoc @SidShirole If u dint know:dis's a secret re #CovaxinCoz it's #TheBest-which Govt's just realized,dis Vax now reserved 4 VIPs,Politicians,Bureaucrats,d Rich, Powerful n Influential n their fams.Add 2 it d fact:#BharatBiotech's been given shit treatment n no Finances 2 expand capacity.",
#  '@Dimensionspect1 I had my first dose of #Moderna on March 11th.  Second dose is scheduled for April 12th.  Feeling great ?',
#  '#SputnikV should be made available whoever has money can obtain it and Gok should focus to support disadvantaged members of the society. #RutoOnCitizenTVHapa. I agree 100%',
#  'Forgot what getting dosed felt like #onedown #PfizerBioNTech',
#  '@MihirkJha #SastaBhiKargarBhi #Covaxin of Bharat Biotech',
#  '@vaimaniki Boss, in US like in many other countries vaccination even given by the private sector is free. Besides both #Covaxin and #Covishield have been approved in other countries w/o trials.',
#  'I received my first dose of #Moderna.I made it way worse in my head ?',
#  '#novavax #COVID19 results may be preliminary but nothing like this has been achieved by #Moderna or #PfizerBioNTech  or #AstraZeneca and one would expect that @DrFaucis1  @drsanjaygupta @BillGates will find time to level with the masses and honestly tell them the significance!',
#  'Update on the AZ vaccine: feeling lethargic and a sore arm but definitely pleased I had it ... am hoping might help with LC symptoms? #vaccineupdate #oxfordvaccine #oxfordastrazeneca',
#  'Kingston surgery . And Aldi car park perfect work Z. Easy to get your vaccine there . #OxfordAstraZeneca',
#  '@disasteradio @tripperhead @klustout .FYI ;Kristie Lu-Stout parroting #CNN\'s "reporting" of skewed analysis &amp; #misinformation, &amp; #disinformation .On-air discussion w John Vause ...even doing sly head-shake at #Sinovac .#MediaBias#MSM #Bias.@aaja @spj_tweets #Sinopharm#ChineseVaccine#VaccinesSaveLives',
#  'What will happen if @JJansaSDS is vaccinated by #SputnikV ??',
#  'Several of my family members got #vaccinated yesterday and more are scheduled for the next few days. I didnt expect to feel such a visceral relief and gratitude. #pfizer #Covaxin',
#  '@MarketWatch $MRNA 151 LONG Best-In-Class #Moderna #COVID19',
#  '1st shot down, only 1 more to go!! #Moderna #COVID19Vaccination',
#  'Has anyone had the 2nd dose of #OxfordAstraZeneca #vaccine #sideeffects was it worse then the 1st? Or better?',
#  'Boomer guy behind me getting his second dose yesterday at #Cleveland\'s @wolsteincenter: "I don\'t understand why we couldn\'t have got both shots on the same day ... we have two arms?!?"He was serious.#csu #PfizerVaccine #PfizerBioNTech #COVID19Vaccination #CovidVaccine',
#  '@CGTNOfficial If #AstraZeneca  was from China  it was going to be potrayed in a different manner but thanks God it was from the imperialist  nation. Nomatter how their propaganda machine tried  to  justify it in Zimbabwe we are not interested we go with #Sinovac',
#  '@aslavitt46 Glad to be one of them! #Moderna #Dose1',
#  '@AlexTaylorNews Omg, not that again ????? @WHO confirmed that the AZ jab is safe. I suspect this is due to pressure from #PfizerBiontech as #AstraZeneca said all along that they wont be making profit out of this. This is ridiculous now.',
#  'Unscientific poll but everyone I know who has had the vaccine has had #AZ. I appear to be the only one who has had #Moderna. I am now wondering if in fact Dolly has a plan. An army of Dolly Birds. Hand picked. Who will take over the world ?',
#  'Fever. Headache. #2ndDose #CovidVaccine #Moderna',
#  "Just had my first jab to protect me (and you) from COVID19 and I'm pleased to say our WiFi has improved significantly. Definitely worth it for that alone. Get it in yer!#PfizerBioNTech #NotAJoke #GetVaccinated",
#  "I've already rearranged my schedule so I don't have anything scheduled for work for 2 days after shot two, based on the experience of others. #Moderna",
#  "@TheVeronicaT @renarockss Hi Veronica, Great to see the joy on your faces again, knowing you genuinely are moving forward, and are in better governance. Aussies are dealing with vaccine rollout problems. I don't think we even have #Moderna as a vaccine option. ;)",
#  '@LindaNi121202 @Rob_Kimbell #pfizer and #Moderna making millions in profits on their #vaccines  , the #AstraZeneca  #vaccine is Non profit making . That explains a lot .  #Covid_19  #Covid  #AstraZeneka',
#  '@globaltimesnews Not sure if my Pakistan friends know it , there was duplicate manufacturer from China who manufactured 9 million duplicate doses and added it to supply chain , no one really knows where are those duplicate vaccines and #Sinovac paid bribe to China CCP officials to get it approved',
#  '@business @StanWongWealth Why are we hogging vaccines for otherwise healthy teenagers when the elderly folk in most other countries are still dying in mass and their healthcare systems are incredibly  overwhelmed??#PfizerBioNTech #CovidVaccine',
#  'Younger participants, those not receiving anti\x96metabolite maintenance immunosuppression, and those who received mRNA-1273 were more likely to develop antibody responses. #modernavaccine #Moderna @JohnsHopkinsSPH',
#  'We will meet again, Covid. Only next time, in hell! Fuck you! #secondshot #Moderna#GetYoursWhenYouCan!',
#  '#Moderna and #PfizerBioNTech should open source the #Covid_19 vaccine so anyone with manufacturing facilities can produce more.',
#  'Total doses 42,780,0691st doses 32,849,223 62.4%2nd doses 9,930,846 18.9% uk ?? #vaccine #vaccination #coronavirus #covid19 #pfizer #moderna',
#  'Chipmakers and #pharmaceutical companies were among the biggest drags on the index, with #pharma firm #Moderna down 4.1% and $42 billion market cap #Microchip #Technology down 4%.$MRNA #stocks #StockMarkets #stockmarketnews',
#  '#SputnikV phase 3 trial complete. #Covid_19 #vaccine #AstraZeneca #pharmacy #BankStrike #bankprivatisation',
#  'Excuse me while I do my fully vaccinated jig ?????? #moderna #sciencewins',
#  'Thank you to all the amazing staff @StPiersSEND &amp; @youngepilepsy who organised the #oxfordastrazeneca #vaccination on campus today for all the #students eligible for it #SpecialEducation #LearningDisabilities ???',
#  'Open up vaccination tourism #vaccination #covid #NHS #SputnikV',
#  'Does anyone have a reference/data for the efficacy of the first dose ( only) for #Covishield and #Covaxin ?',
#  'Bharat Biotech confirms deal with Brazil to supply 20 million doses of #COVAXIN@businessline @BharatBiotech #Brazil',
#  'Dang, this #Moderna shot is trippy.',
#  '#SputnikV would replace Vodka as the most famous shot coming out of Russia',
#  '@businessinsider Maga #covidiots are using #HydroxyChloroquine , but their political masters are taking #PfizerBioNTech vaccines. It seems the covidiots love to kill Americans. At this point they are responsible for more American deaths than isis lol',
#  '@degs99 @DrTomFrieden Say whatever u wanna say ! Even #AstraZeneca admitted today &amp; #Moderna is working on a booster shot! So keep ur stupid ideas for urself ! The delay in distribution is because of creating a booster shot! Young r dying more from the new strain WAKE UP',
#  '@adamsonjon @mr_numbers @CraigNikolic @HPIAndyCowper @ShaunLintern Really @pfizer #pfizerbiontech',
#  'I can confirm that after the second shot you can feel rather shitty. Being vaccinated and protecting myself and others is worth it. #COVID19Vaccine #Moderna',
#  "@CTVNews @fordnation will go on air today and start going after the #Moderna delay and not look at the arrival of #Pfizer. He won't even look at the #CovidVaccines sitting in his #freezers. What are you saving those for @fordnation ,you know you can't bring back people when they are dead.",
#  '@guardian #matthankock says there is enough #pfizer and #moderna vaccines for under 30s, Europe bans it for under 60sWhy do they think this makes me as an over 30, accept #astrazeneca ?!!!',
#  '@ONThealth @GovCanHealth @cafreeland @JustinTrudeau @MarciIen SputnikV is safe and effective, can we get that vaccine approved In Canada and speed up this vaccination process? #LargestVaccinationDrive #Russia #COVID19 #imdone #vaccine #canada #SputnikV #Ontario #DougFord #bored',
#  '#Poland will use up the first batch of 300,000 #PfizerBioNTech #coronavirus #vaccines by Monday, but a second identical batch is expected to arrive in the country on the same day, the head of a state reserve agency has told PAP.',
#  '@WZHappening #moderna gang for me, wbu?',
#  '3 women given rabies vaccine instead of Covid-19 jab in UP ????Is this a new scam in india ?? #Covaxin #CovidVaccine #coronavirus #lockdown',
#  '@tequiladiva @dailymaverick @A_C_D_P @SahariIvsa @SAHPRA1 Or a more natural, traditional vaccine, like the inactivated virus virus vaccine, #Covaxin.',
#  '@kakar_harsha @ImranKhanPTI #JaiHind@kakar_harsha sir, with #Sinovac being not yet approved by @WHO, also this human - @hope11786 must also know that the second vaccine of ?? - #Sinopharm is the one that has 73 side - effets. This has been brought forward by none other than, a #Chinese doctor.',
#  '@Sibasa1Sibasa @edmnangagwa We are not taking the J&amp;J rubbish here in Zimbabwe. Look at yourself, using the J&amp;J review nonsense to critique #Sinopharm. For your information we are using the safest #COVID19Vaccine in the world. #Sinopharm is trusted world over.',
#  'Got my 2nd covid vaccine shot and all of a sudden I get amazing 5G signal on my phone, weird....#Moderna #CovidVaccine #COVID19Vaccination #COVID19 #GetVaccinated',
#  '@SputnikInt @CharlesMichel @sputnikvaccine Michel fails to recognise that most people in the EU want a choice of vaccines and that #SputnikV is number 1 choice for many people.',
#  'To my #medical #Doctor Twitter friends: who exactly is evaluating the risks associated with the #SputnikV #vaccine? as I understood it uses very similar technology to #AstraZeneca? #PublicHealth #COVID19Vaccine #data #Statistics #bloodclot #VaccinesForAll',
#  'Arm is a bit sore at injection site this morning but nothing serious. #CovidVaccine #OxfordAstraZeneca I also got a little card to show I had my first vaccine #VaccinesWork',
#  '@VHansenSCRadio I get my first #Moderna shot next week. I wont believe it until the needle is in my arm',
#  'Soriyan??: India cannot manufacture even a bell pin if British leaves. India 2021 ??: Exports vaccines to England and to rest of the world . #Covaxin',
#  '@Scots_wifey @Channel4News @GOVUK Knocked me for six. Was ill for a week. Then fine for a week. Now all I want to do is sleep and that was ages I got it. I had the #OxfordAstraZeneca one.',
#  '@RichaChadha @anweshbose What to expect from illiterate #bollywood fake people.#COVAXIN #SerumInstituteofIndia',
#  'We are at the point of not knowing if we are having vaccine side effects, or menopause symptoms. Day 16. We seriously considered going to a doctor, still logging wacky stuff. #CIDP #EDS possibly #MCAS #vaccine #Moderna',
#  "Sputnik V COVID-19 vaccine to be launched by early June, to be priced at $10, says Dr Reddy's#SputnikV #drreddy #Russia #russian #vaccine #VaccineForAll",
#  '#wato referred to #PfizerBioNTech and #oxfordastrazeneca #vaccines but went onto only refer to #Oxford when it was deemed to be potentially better in one respect ?',
#  '@hend_mana #UAE #China Proud partnership and significant milestone ! #Sinopharm #CovidVaccine',
#  'Wear a mask. Take your vaccine! COVID-19 is painful ? #CovidVaccine #Moderna #COVID?19',
#  '@drharshvardhan Center should declare the #Vaccines Quota and let States create their Vaccination Priority and execution plan .. Give flexibility to States to include Vulnerable below 45 too ..announce no more export deals of #Covaxin and compensate @BharatBiotech for the losses',
#  "I'm currently waiting to get my 1st #CovidVaccine #Moderna ?",
#  "@nytimes Well, the US should've listened to the US people...we didn't want Johnson&amp; Johnson. Their products are unreliable and usually recalled. Their name is popular but they're they're merchandise is usually recalled or defective. #Phizer #Moderna ? J &amp; J",
#  "Okay. So it took about 24 hours for the #Moderna side effects to pop-up after shot #2. Arms sore, fatigued slight headache and hot flashes. Can't complain too much but the side effects can't fade away quick enough.",
#  'To further augment #COVID19Vaccine supplies, production of #Covaxin to be increased from the current 1 crore doses/month to 10 crore by September 2021 by enhancing capacity &amp; adding more manufacturers : @DrJitendraSingh',
#  'Second vaccine ?, thanks @KPSanJose! #vaccine #vaccinated #Moderna',
#  'Next morning: arm is a little sore, milk headache, also tired but that may not be related to the vaccine. Overall, mild reaction. #moderna #COVID19Vaccine #ms #MultipleSclerosis',
#  'The 2nd #Moderna shot ? - I was warned abt so I got #prednisone b4 to survive the after shot battle, round 1 shot was rough, part 2 OMG...48hrs a blur. Hard hot red knot at injection site now it itches, ice paks used. B happy when #covid19 is gone',
#  "Does anybody know about any side effects of these vaccines on Pancreatitis patients? My mom is a pancreatitis patient and I'm worried  for her vaccination... which one will be better and without any side effects? #Covishield #Covaxin",
#  'So I have had the weirdest reaction 2 weeks after the 1st dose of #Moderna: swollen, hard, red, hot, tender deltoid. Low grade temp. Fatigue. Anyone else reporting this so long post #vaccine? @ashishkjha @ScottGottliebMD',
#  "Got my 1st #vaccine shot today!First round of #ModernaIf we all do our part by getting vaccinated and continuing to #maskup, we're gonna #CrushCOVID ???",
#  '@sudhirmehtapune We need to keep 1 lac as a daily target......#Covaxin  needs to be made more available. #Covaxin and #Covashield both should be made available in equal measure....#Pune',
#  '#Covaxin Taken Off Clinical Trial Mode, No Consent Forms Needed Now.The DCGI decision is based on the interim efficacy data released by the company.Till now vaccination rollout was an mass clinical trials?',
#  '@PolskieRadio24 @wybranowski In #slovakia we had in contract that health minister has to approve #sputnikv it to avoid testing from national regulator. Govt collapsed, tests started and russians freaked out. Same story with corrupted politicians everywhere.',
#  'Hey guys,Please reply to this as this is urgent. I have got my in laws registered for covid vaccination and my MIL is diabetic as well as High BO patient. So want to know which vaccination should she go for #Covaxin or #Covishield ?',
#  'Really want to thank @DollyParton because she made #Moderna possible for so many! Thank you so much! I loved you then and I love you even more now!! ?  #becauseScience #Formylovedones #Grateful #Trust',
#  '#Breaking: #Moderna cutting shipment to #Canada due at end of April from 1.2-million doses to 650,000 doses.',
#  '@REDBOXINDIA Go tell that to the govt. whos busy playing the red tape game. And pacifying lobbyists and the west alike while delaying approval to the highest efficacy rated vaccine in the world. #SputnikV #drreddy #DGCA #Scam  @desaipankaj1 @INCIndia',
#  'Could the next step from the criminally incompetent #eu be to not allow British people vaccinated by #OxfordAstraZeneca into the #eu as it "doesn\'t work"?Wouldn\'t put it past them.',
#  'Is there availability of #Covaxin in #Ahmedabad. ?',
#  '@narendramodi Yes got my covaxin first shot. Can we get the central govt to increase supply for #Covaxin  so that for 2nd shot we not worried on supply? Right now hospitals are reporting short supply for covaxin.',
#  'Dr Reddy Tells Us: #SputnikV imports to begin End of May / Early June#VaccineForAll #vaccination #COVID19',
#  'Phase 3 #clinicaltrials Trial of #COVAXIN by @BharatBiotech, shows 81% efficacy. Independent data safety &amp; monitoring board evaluation, shows #vaccine is well-tolerated &amp; efficacious against SARS-CoV-2 across a wide range of age groups &amp; variants in the country#CovidVaccine',
#  "@emmakennytv @PHE_uk Apart from the #oxfordvaccine, the #Moderna #PfizerBioNTech are both forms of 'gene therapy'. They legally cannot be described at vaccines. Mary Ramsey is wrong.",
#  'Anyone who has ever worn a mask has the sense to get the vaccine!! Get as many as you can and HURRY!! DEMAND what you deserve! #WearAMask #VaccinePassport #vaccinated #vaccines #COVID19 #Pfizer #Moderna #AstraZeneca #JohnsonAndJohnson #Oxford #Masks #MaskUp #DoubleMask #SARSCoV2',
#  '@thesuniljain @narendramodi @drharshvardhan @SerumInstIndia @BharatBiotech Panacea Biotec has announced to manufacture 100 million doses of #SputnikV . We must give emergency approval to #PfizerVaccine to produce in India asap. This will further increase the supply of vaccine in India. #VaccinationDrive #IndiaFightsCorona -3-',
#  '@narendramodi #TAXPAYERS Income tax payers should be given vaccine first....They are only 3 crores #COVAXIN If they die, how will the country survive...! @BharatBiotech?? @FinMinIndia @indfoundation??        @hindupost ?? @HinduITCell @OpIndia_com @republic @PuspendraTweet',
#  '@GovPritzker #close the #state again #fat #ugly you have to follow your bosses wait 3 to 5 yrs when the #people who are #vaccinated will see the side #effects @CDCDirector @CDCgov #Moderna #Pfizer #johnsonandjohnson #USA',
#  "@Donaldverger @EricTopol @moderna_tx @NEJM Two shots of #Moderna provide protection against even the more concerning variants like #B1351 but they're developing a booster anyway, which will surely bring efficacy against symptomatic illness back up to super high levels (+90%).",
#  'Trending Topic: #johnsonandjohnson, #Bridgerton, #Moderna e #Atalanta.',
#  'This kind of attitude make our PM  different from other .            #Covaxin',
#  'Got my first dose of the #Moderna vaccine!!',
#  'FWIW, the #Moderna #COVID19 vaccine side effects after the 2nd shot are the real deal. Woof. Body aches, major fatigue, headache. For me, at least. BUT, this is a small price to pay to be #vaccinated.',
#  '@JayNdubiwa @nickmangwana @MoHCCZim We are ordering #Sinopharm n #SputnikV so clearly those are the two cleared for use here....read the accompanying pictures for crying in a bucket',
#  "For God's greater glory! 1st dose done! #COVID19Vaccination #vaccinated #Sinovac #formyfamily",
#  'In line for my 2nd dose of #Moderna #COVID19 #vaccine',
#  '@Roland_84_E Current ranking:1.) #Soberana 2.) #EpiVacCorona3.) #Pfizer4.) #Moderna',
#  'Just a thought ... if the clotting side effects from the #AstraZenaca vaccine are in women, why not give it to men and divert the #Moderna and #Pfizer to the female population? @GovCanHealth',
#  '@LibDesi @MaliniP #Covaxin ?? , made by Hyderabad-based Bharat Biotech International Limited, has been declared "Safe, Immunogenic with no serious side effects" by Lancet',
#  'The US is administering more than 3 million doses a day on average over the past week. But can we out-vaccinate the two new strands in California?#GetVaccinated #ShotForSam #Moderna #vaccines #vaccinated',
#  'Second Vaccine dose done! ?? #getvaccinated #OxfordAstraZeneca',
#  'Many excuses are being given for #Japans inexcusably slow #vaccination rollout,including EU export limits. But it should be noted that Japan still hasnt approved #Moderna (mostly US made as is much of #Pfizer) All as case rates increase. #COVID19.',
#  '#SputnikV can be the next vaccine to be approved in India.Vaccine has shown 90%+ efficacy.@drreddys seems to be the manufacturer.Hope it will be available to the public at large without age capping.',
#  'First vaccination received this morning. Very efficient process and a real sense that something momentous was happening. #oxfordastrazeneca  #vaccine',
#  'Had my first vaccine yesterday #oxfordastrazeneca and no side effects whatsoever! ??',
#  '@ANI Happy that he has taken #Covaxin, it shows enormous confidence in our indigenous vaccine. I am waiting for my turn to get #Covaxin as I believe in this vaccine more than others.',
#  "Horray!! Got my 1st dose of the #Moderna vaccine today and I am soooo fucking relieved!I've worked this whole time, surrounded by construction people and patients. Even though I observed the safety measures 100% - I was still at risk. Huge #relief.",
#  '3-2-1....FULLY VACCINATED!!!!! Woohoo!!!Thank you @POTUS and team!! @WhiteHouse @VP @WHCOS @XavierBecerra @SecBecerra @HHSGov @CDCgov @CDCDirector #Moderna #StopTheSpread #vaccinated',
#  '#Moderna shot 1 in the books. Happy to get the #COVID19Vaccine today! #WearAMask #StayHealthy',
#  'I just got my second vaccine. I feel so relieved and grateful. #Moderna  #vaccinated #vaccine',
#  "Got scheduled for my Fauci Owchie this Friday!The nice new mRNA kind!(seriously, the tech behind this vaccine could go on to cure many, many diseases) Alongside my fellow #EssentialWorkers, I'm finally feeling #Hope#vaccine#Moderna",
#  '#Moderna #COVID19Vaccine 24 hours after Dose #1: Arm is slightly sore at injection site. Thats it. Onward, Science Soldiers!',
#  '$pfe &amp; $mrna Covid vaccines 90% effective at lowering risk of disease-3,950 health care workers studied, showing real world stats of the vaccines -2 weeks later showed 80% effectiveness#COVID19 #Pfizer #moderna',
#  'So 36 hours in and heres what has happened so far. Arm was really sore, but not swollen, last night but not much at all today.About 12 to 16 hours in I felt feverish but no temp. I felt really tired as well, I slept all night uninterrupted. Today feel just fine. #Moderna',
#  '@agitpapa Just waiting to see if the Europeans have any sovereignty to approve #SputnikV quickly or the US will just make them wait for #Pfizer to fully supply the US market and then start supplying to the EU post that.',
#  "@VishnuNDTV Approval of #Russia's #SputnikV with just 21 days interval will ensure more people will get both jabs &amp; quickly; faster immunization &amp; better Efficacy, Safety too#Covishield #COVID19India  #Covid19 #vaccine @MoHFW_INDIA@drharshvardhan @mfa_russia @RusEmbIndia @sputnikvaccine",
#  'Got my first vaccine shot today #Moderna',
#  '@sciam , could you guys please confirm that it IS a typographic error, 82% cited as efficacy after one dose?In case it is not a typo, could you clarify the source of the number? NEJM says 52%Important for the vaccination strategy being implemented in Mexico.#PfizerBioNTech',
#  '@jmt_18325 Sadly, with clinics closing in Ontario due to flaky #moderna supplies, #AstraZeneca being shunned by the public at large, and #JohnsonandJohnson off the market also due to clotting, this #Canada #vaccination goal might likely be achieved in June, 2022.',
#  '@Mikel_Jollett I also got #moderna 2 days ago, yay!! Luckily, I hardly had any side effects ??? Just some pain in my arm and a bit tired.',
#  'So far 2nd Moderna shot just giving body aches, headaches &amp; sweating. So really just extra diabetes symptoms.#2ndShot #Moderna #vaccinated',
#  '@labyrinthweaver Surprisingly (and happily) received my 1st #Moderna shot Friday.All set to sleep in guilt-free. I know side effects for the 1st shot are typically minimal. Expected to at least feel tired. Nope. Wide awake after 7 hours of fitful sleep. Unreal.Post-vax elation on the horizon.',
#  '@Ocugen Is it coming to the USA though? $ocgn #covaxinBiden implied he already ordered enough.',
#  '@fespinolaprieto @sputnikvaccine These ridiculous ceremonies are part of the contract - it is needed for russian propaganda which is selling millions of doses of #sputnikv but deliveries are just 1/1000 of that. What approval it gets in Paraguay? contracts are made to avoid national regulators tests in labs.',
#  '#Moderna #2: Feels like the day after my first full contact rugby game. Thee body aches are no joke. Also feel slightly concussed. or stoned. hot and cold at the same time.but i?d take this over getting covid (or worse, spreading covid in my community)',
#  '@Mahesh10816 I think it should be #Covaxin bcoz the trials were solely conducted on indian citizen.. so the efficacy would be higher for Indians with same or closer genes',
#  '@emilymxller #Moderna Squad dropping in to say you suck',
#  'registered for #Moderna vaccine with the whole fam ? cannot wait!',
#  '@ColSanjayPande @ikaveri Yes sir, definitely...if the vaccine is #CovishieldFor #Covaxin the schedule remains same (4-6 weeks)...just to re-emphasize/ clarify',
#  "@ShellyGivan @TaiChi_John @JoseteVentura @ScientistMel @minibeastmayhem @BrianBrachiopod @TwiHusband @Drstevenhobbs @HayesPope @jaarete1 @JMPeck69 @anartdecodiva @Monkeys2Fly @nazani14 @AngharadBond @gunsnrosesgirl3 @kenserlore96 @TallDavid @TTDerandere @Bolshoibabushka @Mammal01012021 @IrvingForbush2 @traderttt9 @JRLgdnr I didn't own a pet rock because I had a functioning brain. But I did observe the astoundingly gullible ... by now there are no surprises.And fully protected, weeks past 2nd shot. No side effects at all.#Moderna",
#  "One #Moderna shot down, one to go!On a related note, I once worked on a video game about #QueueingTheory There's definitely some interesting math there but for obvious reasons it was probably more fun to program than to play.#Vaccine #WorthTheWait",
#  '@BharatBiotech @DrKrishnaElla @SuchitraElla @CNN @FoxNews @CNBC @ABC The best vaccine in the world! We need it in the USA! #Covaxin #covaxinus',
#  '@ManchesterHCC @Dr_PWright @GMSCNews @GM_HSC @GMEC_SCN @doctormkumar @ManCityCouncil @AndyBurnhamGM important day for GM. Cant stress enough the importance of Covid -19 vaccine #CovidVaccines #PfizerBioNTech #Covid_19 #staysafe',
#  "@ShropCommHealth when will the #vaccine be administered to residents of #Shrewsbury #carehomes? It's already happening in Wales &amp; NI. Day 10 since the first nonagenarian received the #PfizerBioNTech jab. My Mum is 97 &amp; so vulnerable. How much longer?",
#  '@ANI why we are not getting #Covaxin we forced to take #Covishield only?',
#  "@niveditatanna @doc_mamta @ANI It's related to capacity constraint of bharat biotech. They are ramping up the production! Will be sorted soon. #Covaxin #VaccineForAll #COVIDSecondWave",
#  "@Eiggam5955 After 2nd #Moderna Shot: I'm still tired &amp; had extreme vertigo for a day. No issues with 1st shot. Sore arm both times. #Modernashot #CovidVaccine #covid #Corona #CoronavirusPandemic #coronavirus #CovidIsNotOver",
#  'Oh boy the next few days are going to be very uncool for the guys promoting the purchase of #SputnikV in germany...',
#  "Hello, Yesterday I had registered my mother's name for the #Covaxin on the Arogya Setu app. After successful registration, I received a message today, in which the registration was cancelled. Please assist. @SetuAarogya @MoHFW_INDIA @drharshvardhan @DrHVoffice",
#  'Chinese vaccines dont have very high protection rates, top health official admits #Sinovac -AP',
#  "@ctvottawa You don't see the US giving us 1.5M doses of #Pfizer or #Moderna  ?",
#  "Soon we may have first &amp; only non-experimental Covid vaccine in U.S. @Ocugen planning to bring India's #Covaxin to the U.S.  Final PH III data due mid April, immediately apply for EUA, India ships initial 100 million doses. Effective w/ variants, safe children's vax. #vaccine",
#  'Think your COVID shot is a one and done thing. Think again. Moderna hopes to have Covid booster shot for its vaccine ready by the fall. They are NEVER going to stop. #moderna #PfizerVaccine #JohnsonandJohnson',
# ...
#  'No day without any breaking news from Germany ??? #COVID19 #lockdown #vaccine #SputnikV #vaccination #Merkel #spahn #laschet #CDUKorruption',
#  'Got #moderna #vaccine part 1. Lets do this San Diego.',
#  "I live in a country where a Farmers have all the rights to sell the crops at their own price. But pharma company can't sell can't even at discounted price of their choice.Vaccine banane wali companies bhaad me jaye humko free mein vaccine do#Covishield #Covaxin @adarpoonawalla",
#  '@labyrinthweaver Get my 2nd dose next week!!Qualified tier 3 thru #ChoctawNation Health.... Oklahoma Their system was the most efficient program Ive have ever gone thru. Made an appt and a week later I was in...Registration and shot only took 2 mins then observe for 10#Moderna',
#  "@MeghUpdates @drishti16966 I am surprised the great journalist of india @ravishndtv has not yet asked #Covaxin banane wale 'Kaun Jat Hain' !! #Reservation",
#  '2nd dose done.  #PfizerCovidVaccine #Pfizer #PfizerBioNTech #atc #atsarehealthcare',
#  '...in coming May month only. Was that a joke or some scam which hospitals are running?Kindly look into the matter.#Covid_19 @himantabiswa @sarbanandsonwal @drharshvardhan @MoHFW_INDIA #Covaxin #CoWIN #coronavirus #COVID19',
#  '@smerconish I participated in the vaccine study. Your body will feel a big difference between the first and second shot!  You definitely need 2 shots. #PfizerBioNTech #vaccine #Pfizer ??????????',
#  'What doe the "average Canadian" know about #SputnikV and how it could solve the Canadian #vaccine shortage?Serious question.',
#  'China wants to work with the UAE to produce anti-virus vaccines at an affordable price to the world??????#Sinopharm#COVID19#CovidVaccine',
#  'Got my second dose of the #Moderna #vaccine today!! ??',
#  '@WHO @DrTedros 500 deaths today in Italy. Shame to everyone! #SputnikV could save them.',
#  'I am so lucky to have been recognised as a key worker and received my first jab on Thursday.  #NHSheroes #COVIDVaccination #PfizerBioNtech #honoured',
#  'Hello @pfizer @SerumInstIndia @BharatBiotech,@adarpoonawallaCan you please add serotonin to the vaccine?We all need it!#PfizerVaccine #PfizerBioNTech #seruminstitute #BharatBiotech #happyhormones #serotonin',
#  '@luizrmgarcia @sputnikvaccine @jensspahn @uniaoquimica @anvisa_oficial USA pressured Brazil to not get #SputnikV',
#  'Iam pretty sure now, vaccine works only when you click a pic. getting it and upload same on net.#Covaxin #mondaythoughts',
#  "2. what i forgot to mention: this FEELS LIKE QUARANTINE. CAN'T DO MUCH, JUST SITTING AROUND, ADVISED TO SLEEP AMAP...,(April 17, 2021; 6:00 HKT) #coronavirusVACCINE #coronaVACCINATION #coronaVACCINE #covid19VACCINATION #covidVACCINATION #PFIZERBIONTECH #PFIZERvaccine #PFIZER",
#  "In the chair getting my #Moderna COVID vaccine. I've socially distanced for a decade, but, this is the right thing to do.",
#  "CARL LOUISE ALAZAQUI @carlosalazraqui I can't believe you just said that #Moderna was the Olive Garden of vaccines on @StephMillerShow Thems fightin' words, dude!#TeamFunkyColdModerna #TeamIAmAModernaGirl",
#  '@swentol yes, they gave #slovakia government a condition to approve it without a control from national regulator. government "fell" (due to #sputnikv ) and SUKL started tests. Now, russians are demanding to give the vaccine back, because they are afraid of outcome.',
#  '@JoeBiden by next Christmas a push to keep 1 trillion to help #americans and keep them poor! Or kill as many as possible for #HerdImmunity #PfizerBioNTech is 85% effective and can vaccinate all Americans whats happening',
#  'EMA starts rolling review of the #SputnikV  #COVID19  vaccine',
#  "@LeoEarthMonkey @nytimes @ukcolumn It's been working well for those who take it (have it prescribed) in early presentation preventing more than 85% of hospitalisations completelyNow I'm not a doctor but that seems to me to be as good as (if not better) than the efficacy of #AstraZenaca #Pfizer &amp; #Moderna",
#  'Follow the money &amp; transparencies: #OWS Gov Funding for #Moderna, #$1.6B for #NOVAX, #Pfizer, #JNJ = @NBCNightlyNews #CovidHaulers healthily kids now sick. While @InovioPharma #INO4800 with its 100% safe peer review gets held back with no support from @WHCOVIDResponse @US_FDA?',
#  '2nd #Moderna dose just now. #COVID19 #GetTheVaccine #MentalHealthProvider ??????',
#  '?Calling Health Care Professionals IF you were offered one of the extra doses of the #PfizerBioNTech vaccine (that are currently being discarded) would you have it yourself ?@HelenRSalisbury @RammyaMathew @rich_pratt @J_bagpuss @DrShanHussain @WeGPNs @Gpnsnn @RSharmaPharma',
#  'vaccine back in January. The ICMR had then said that restricted use in emergency has been granted based on immunogenicity data which was generated based on phase 2 clinical trials and had said that the Clinical Trials Rule 2019#Covaxin #BharatBiotech Phase 3',
#  'My parents got their second jab today. Thanks to state and central health authorities. Really feeling relieved now.#CovidVaccine #vaccinated #VaccinesSaveLives #Covaxin#CoronavirusPandemic',
#  '@Ocugen when can we expect phase 3 complete data and fda approval for #covaxin',
#  '@velvetcanyon73 @MariaBelle09 @tanasbeb @MannyMua733 Sometimes $$$ is what they believe in the most.  #vaccine #Pfizer #AstraZenaca #Moderna #JohnsonAndJohnsonVaccine',
#  "Has #RahulGandhi taken the vaccine? He's eligible for #vaccination. He blindly opposes everything the #government does. So my doubt? is hell oppose the vaccine as well?? ?#vaccine #Covaxin #COVID19India #Congress #VaccinationDrive #SoniaGandhi #Italy",
#  "Has anyone else who's gotten the first dose of the #Moderna vaccine had referred pain to the head area on the same side as the injection site? I can't tell if it's just my sinuses or referred pain from my arm (which hurts like HECK). Grateful, but ow.",
#  '1st dose down, one more to go.  #Moderna',
#  '@PMOIndia @narendramodi #Covaxin and #covishied may be effective against COVID-19 Virus with 85% Efficacy Honorable Sri @narendramodipm_ ji sirHonorable Sri @NitishKumar ji sir',
#  "Holy crap, that second dose of #Moderna was rough! I ate a whole box of Popsicles and a gallon of apple juice. Pounding headache, fever, severe body aches for 36 hours...glad that's over! #vaccinated #CovidVaccine",
#  'There were six deaths during the late stage #PfizerBioNTech trials, but the FDA says this raised no safety concerns.',
#  'Last night, #Pakistan?? received the first shipment of privately-imported Russian?? #CovidVaccine, Gam-COVID-Vac or #SputnikV, at the Jinnah International Airport in Karachi.#CoronaVirus #COVID19',
#  'Also, Govt should look to approve other vaccines similar to  #SputnikV which has been approved for emergency use, By bringing in mass population under vaccination spread can be controlled. The idea of #AatmanirbharBharat cannot happen if vaccination is not rolled out to',
#  '@Conservatives @BorisJohnson @10DowningStreet @Conservatives when will the inevitable u-turn occur with regards to the 12-week delay between Pfizer jabs? @pfizer state 21 days, and @EMA_News state the delay should not exceed 42 days.#PfizerVaccine #PfizerBioNTech #ToryCovidCatastrophe',
#  '@SicilianoSum @sputnikvaccine @mfa_russia @repubblica @Corriere Who cares about them! The arrival of multiple vaccine options presents an opportunity to allow people to make informed choices based on their preferences, including the relative weight they attach to efficacy, avoiding adverse effects, waiting times, and convenience. #SputnikV',
#  'Vaccinated 111 patients @WoolwichLNP ? in just the morning shift today ! (8-12.30) just amazing teamwork.  #Covid19UK #COVIDVaccination #OxfordAstraZeneca #AstraZeneca #COVIDVaccination #NHS #pharmacy @NHSGreenwichCCG @NHSSELondonCCG @Royal_Greenwich',
#  "@ChapelGuilt @sergiocarvalho @SPeitsch @jacobsonware I don't think UK does it with #PfizerBiontech, does it?",
#  'Get an appointment to have my first Anti-COVID jab for next week !!! #PfizerBioNTech',
#  'the move will help to increase the pace and coverage of vaccination at time when the second wave of the pandemic is raging in india. #CoronavirusVaccine #SputnikV',
#  '@thomaskaine5 I took the first available which was #PfizerBioNTech',
#  '@sharkyrae @ImSpeaking13 Better off not getting J&amp;J with uncertainty right now. I had both of my #Pfizer and my son is getting ready for his 2nd #Moderna next week!! Good luck to u! ??',
#  'Received shot two of #Moderna vaccine last week. 48 hrs of unpleasent side effects, feel great now. #VAHospitalColorado has been efficiently giving shots as they get vaccine in the hospitals. #Grateful #KudosToVAHospital #ThankfulHealthcareWorkers',
#  'Khairy told a press conference following his shot that he was feeling #well. The minister stressed that the #Sinovac vaccine had been used in many countries and by state leaders including ??Indonesian President Joko Widodo and ??Turkish President Recep Tayyip Erdogan.',
#  'Covid arm update: still itchy. Comes in waves of like "OMG I MIGHT DIE IF THIS DOESN\'T STOP ITCHING" to "Yeah, that\'s annoying, but I can deal with it."#CovidVaccine #Moderna',
#  "Getting my 1st #Moderna shot tomorrow! I'm so excited!#VaccinateAll58 #COVID19Vaccine",
#  '@KremlinRussia_E @NAkufoAddoThe only vaccine against COVID 19  I trust and will accept as a Ghanaian is Russia Sputnik V Vaccine, aside that none.#JoySMS  #SputnikV  #TV3GH',
#  'This is Obvious, #Sinopharm is injecting a deactivated #Coronavirus so yes after getting Vaccine you can get Positive within 2 days #imrankhanPTI #ImranKhan',
#  'based on background levels, a billion single dose (J&amp;J) vaccines could mean:900-2200 cases of GBS w/in 6 wks1500-3700 cases w/in 10 wks of a 2 dose vaccine (#AstraZeneca, #Pfizer, #Moderna)"We must be careful to avoid misattributing adverse events to the vaccination program"',
#  '10 Days Post #Moderna So Far So Good w/Itchy, Sore w/Pain &amp; Sm.Lump At Injection Site.????#Covid #Covid19 #COVIDVaccination  #CovidVaccines #modernavaccine #Coronavirus #Corona #CDC #UPDATE #COVID19Vaccine #vaccinated #vaccine #vaccination #VaccinesWork #VaccinesSaveLives',
#  'Fully vaccinated. #Covaxin . Feeling ok. Thank you Ministry of Health.#Mauritius ??',
#  '2.5 hours #postvaccine not much but anxiously waiting. #COVID19 #PfizerBioNTech #VaccineDay',
#  "@RobynUrback agreed. &amp; the only thing I know for certain is want the #SputnikV vaccine-but can't get it. Y not? Approved in ~40 other countries?  Exasperating beyond belief. @justintrudeau @liberal_party fiasco. #cdnpoli @cbcnews",
#  '@Reuters Aztra zeneca kills!! O want my #SputnikV',
#  '@PTI_News I will take only #covaxin and if it is not available then will go for #Covishield',
#  '@SidShirole @aparanjape Latest update: there were only 4 people for the 2nd #Covaxin dose at Joshi hospital at 4:15 PM. So they were sent away and asked to come on Monday.',
#  '@MattHancock @andy4wm Of the 79 people who took the AZ vaccine developed blood clots, 19 died. So if I take the #oxfordastrazeneca vaccine, and develop a blood clot I have a 24% chance of dying...As opposed to the 0.5%(ish) chance of dying from covid...#bbc #vaccine',
#  'Happy Easter everyone .  My arm is killing me from this #moderna #COVID19 Vaccine shot .',
#  '@m_ebrard Following talks between Foreign Ministers Wang Yi #China and @m_ebrard @SRE_m #Mexico The vaccines #CanSino #Sinovac against #COVID19 have been authorised by @COFEPRIS. Congratulations @SSalud_mx, @gobqroand all the staff @DromexGroup #Queretaro where the vaccine will be bottled',
#  'Are the Covid Vaccines going to be equivalent of the new houses since people canceled Harry Potter? #covid #COVID19 #HarryPotter #moderna #JohnsonandJohnson #Pfizer',
#  'Feel blessed to have received my first jab today, thanks to my school district and city health dept. holding a clinic for educators to be inoculated. Keep the momentum going! #Moderna #vaccinated #CovidVaccine',
#  'Got my second dose of the #Moderna #vaccine today!! ??',
#  "World countries approves #COVAXIN and #COVISHIELD WHO hails our vaccines and vaccine production capabilities. Congress Chamcha's &amp; Leftists questions our #MadeInIndia vaccines and misleading people by wrong information. Glad that @MoHFW_INDIA gave befitting reply to @TS_SinghDeo",
#  '24 hour post #moderna vaccine and thankfully no side effects other than a sore arm ??',
#  "I got my 2nd #Moderna this morning. Tomorrow is my husband's birthday. I told him given what we hear about the 2nd shot, I might not be up to celebrating. He said, Where we we going? Good point. #vaccinated #vaccinateny",
#  'Its a problem that the #CDC and the #WHO jockey for pharmaceutical companies! Its unethical and immoral! #Pfizer #Moderna',
#  '@HPPublicHealth Questions:~ why are other Health units automatically booking 2nd appointments for people when they make their 1st appt. online?~Also my age group 55 &amp; up can book online for #Pfizer &amp; #Moderna in other Counties?',
#  '@BBCRadioScot Seems the European countries arent so mental after all eh?!#oxfordastrazeneca #oxfordvaccine #bbcgms',
#  'The morning after my first covid shot: No spider powers so far. Not even so much as a lizard scale. Very disappointing :P But seriously go get your vaccines people #COVIDVaccination #Moderna',
#  '@drharshvardhan A big problem is few people on social media are making it #Covishield vs #Covaxin battle ,even in this critical vaccination period. It is creating confusion, chaos &amp; anxiety among citizens regarding effectiveness of each vaccine @CovidIndiaSeva',
#  'Which all states have got #covaxin vaccine ? @drharshvardhan @narendramodi Believe no #Covaxin in HP. Only #CovishieldVaccine available.',
#  "@ofarrelltalent @UFroggy I got my vaccine shots! I am relieved. It's scary on the front lines! #Moderna #PT",
#  'One shot down one to go. #Moderna #VaccinesSaveLives #PandemicLife #Thankful ?? #MoneyBaggJoe',
#  '??? to @narendramodi ji for putting cap on Covid Vaccine price otherwise poor will be at loss #COVID19Vaccination #Covaxin #COVID19Vaccine #NarendraModi',
#  "@seanwhelanRTE #Moderna vaccine procurement doesn't fit the #UK #BraggCine narrative.However, #EU should be making some positive noises about it, but without adopting the UK #BraggCination megaphone approach.#r4today #Newsnight",
#  '@CherylDewitt10 @Our_DA @jsteenhuisen The Americans said that their #PfizerBioNTech vaccine is also for the mutation.',
#  '@BBCPolitics #marr @OliverDowden #Moderna already in #Belgium. Why not in England? @BorisJohnson s #VaccineNationalism missed that one!',
#  '#Moderna began testing its #Covid #vaccine in babies and young children.NYT',
#  '@nickgutteridge Safe to assume our friends &amp; partners of the #EU27 will suspend the IPR on the #OxfordAstraZeneca jab have Sanofli produce it illegally then claim it to be safe because it`s made in the #EU#FTEU',
#  '@HPBrewer Figures. We get the one vaccine NOT made in Michigan. But, it works! #Moderna',
#  'Does #CoWIN schedule 2nd appointment considering the vaccine in first dose? Had #Covaxin as 1st dose and now its hard to find center for 2nd. Only a handful centers across entire #Pune. Any idea? #vaccine #MaharashtraNeedsVaccine',
#  '2nd shot done, Buchnevich putting on a show, and deGrom on the bump. It is a good day #Moderna #LGR #LGM',
#  '#ExcelsiorPass #excelsiorpassport Can anyone tell me why the Excelsior passport gives an expiration date for the vaccination that you have received????? About 3 months out from last shot...#vaccine #moderna #Pfizer #CovidVaccine #covid @NYGovCuomo @NYCMayorsOffice @NYCMayor',
#  'Update: so its been about 7 hours since my shot ... and my arm is sore. But no more sore than it is with a flu shot. No other symptoms. #moderna',
#  'Getting the news of #SputnikV being approved by the subject expert committee. Now, the vaccination program will get more speed.',
#  ', and will soon begin exploring with Gamaleya Research Institute in Russia to understand whether two adenovirus-based vaccines can be successfully combined. #SputnikV #russia',
#  ...]

# %%
df = pd.DataFrame(columns=['text'])
df['text']=data_noUrl

# %%
# Extracting hashtags
df['text'].apply(nfx.extract_hashtags)
# Out:
# 0                                     [#OxfordAstraZeneca]
# 1                           [#Moderna, #COVID19Vaccine...]
# 2                                               [#Moderna]
# 3                                     [#moderna, #pfitzer]
# 4                                               [#Moderna]
#                                ...
# 23893          [#wuhanvirus, #DictatorofChina, #XiJinping]
# 23894                           [#ChinaVirus, #WuhanVirus]
# 23895                                        [#WuhanVirus]
# 23896                                        [#WuhanVirus]
# 23897    [#BREAKING, #UPDATE#coronavirus, #CoronaVirusU...
# Name: text, Length: 23898, dtype: object

# %%
# Saving hashtage to a column
df['extracted_hashtags'] = df['text'].apply(nfx.extract_hashtags)

# %%
# Cleaning text with removal of hashtags
df['clean_tweet'] = df['text'].apply(nfx.remove_hashtags)

# %%
# Previewing data
df[['text','clean_tweet']]
# Out:
#                                                     text  \
# 0                 Safe and effective. #OxfordAstraZeneca
# 1      The day after the #Moderna #COVID19Vaccine... ...
# 2      @syd_m39 Not a girl but part of the #Moderna c...
# 3      When we can get #moderna and #pfitzer Vaccine ...
# 4                            Officially a #Moderna gay ?
# ...                                                  ...
# 23893  @globaltimesnews Its happening because of you ...
# 23894  @China_Amb_India Opportunist country #ChinaVir...
# 23895  @Respond2Racism @Respond2Racism is a bot creat...
# 23896  @SpokespersonCHN Correction: 1 in every 8 Amer...
# 23897  #BREAKING #UPDATE#coronavirus #CoronaVirusUpda...
#
#                                              clean_tweet
# 0                                  Safe and effective.
# 1      The day after the     My arm is a little sore ...
# 2           @syd_m39 Not a girl but part of the   club ?
# 3      When we can get   and   Vaccine in India?@nare...
# 4                                   Officially a   gay ?
# ...                                                  ...
# 23893  @globaltimesnews Its happening because of you ...
# 23894           @China_Amb_India Opportunist country
# 23895  @Respond2Racism @Respond2Racism is a bot creat...
# 23896  @SpokespersonCHN Correction: 1 in every 8 Amer...
# 23897              COVID caseload in US crosses 40 mi...
#
# [23898 rows x 2 columns]

# %%
# Removing userhandels
df['clean_tweet'] = df['clean_tweet'].apply(lambda x: nfx.remove_userhandles(x))

# %%
df[['text','clean_tweet']]
# Out:
#                                                     text  \
# 0                 Safe and effective. #OxfordAstraZeneca
# 1      The day after the #Moderna #COVID19Vaccine... ...
# 2      @syd_m39 Not a girl but part of the #Moderna c...
# 3      When we can get #moderna and #pfitzer Vaccine ...
# 4                            Officially a #Moderna gay ?
# ...                                                  ...
# 23893  @globaltimesnews Its happening because of you ...
# 23894  @China_Amb_India Opportunist country #ChinaVir...
# 23895  @Respond2Racism @Respond2Racism is a bot creat...
# 23896  @SpokespersonCHN Correction: 1 in every 8 Amer...
# 23897  #BREAKING #UPDATE#coronavirus #CoronaVirusUpda...
#
#                                              clean_tweet
# 0                                  Safe and effective.
# 1      The day after the     My arm is a little sore ...
# 2                    Not a girl but part of the   club ?
# 3           When we can get   and   Vaccine in India?
# 4                                   Officially a   gay ?
# ...                                                  ...
# 23893                 Its happening because of you
# 23894                            Opportunist country
# 23895      is a bot created and sponsored by the CCP ...
# 23896    Correction: 1 in every 8 Americans has been ...
# 23897              COVID caseload in US crosses 40 mi...
#
# [23898 rows x 2 columns]

# %%
# Removing multiple spaces
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_multiple_spaces)

# %%
# Removing urls
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_urls)

# %%
# Removing punctuation
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_puncts)

# %%
df[['text','clean_tweet']]
# Out:
#                                                     text  \
# 0                 Safe and effective. #OxfordAstraZeneca
# 1      The day after the #Moderna #COVID19Vaccine... ...
# 2      @syd_m39 Not a girl but part of the #Moderna c...
# 3      When we can get #moderna and #pfitzer Vaccine ...
# 4                            Officially a #Moderna gay ?
# ...                                                  ...
# 23893  @globaltimesnews Its happening because of you ...
# 23894  @China_Amb_India Opportunist country #ChinaVir...
# 23895  @Respond2Racism @Respond2Racism is a bot creat...
# 23896  @SpokespersonCHN Correction: 1 in every 8 Amer...
# 23897  #BREAKING #UPDATE#coronavirus #CoronaVirusUpda...
#
#                                              clean_tweet
# 0                                    Safe and effective
# 1      The day after the My arm is a little sore and ...
# 2                       Not a girl but part of the club
# 3                  When we can get and Vaccine in India
# 4                                      Officially a gay
# ...                                                  ...
# 23893                      Its happening because of you
# 23894                               Opportunist country
# 23895   is a bot created and sponsored by the CCP to ...
# 23896   Correction: 1 in every 8 Americans has been i...
# 23897   COVID caseload in US crosses 40 million medic...
#
# [23898 rows x 2 columns]

# %%
# User defined function to get the sentiments
def get_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity
    sentiment_subjectivity = blob.sentiment.subjectivity
    if sentiment_polarity > 0:
        sentiment_label = 1
    elif sentiment_polarity < 0:
        sentiment_label = -1
    else:
        sentiment_label = 0
    result = {'polarity':sentiment_polarity,
              'subjectivity':sentiment_subjectivity,
              'sentiment':sentiment_label}
    return result

# %%
# !pip install TextBlob
from textblob import TextBlob
# Out:
# Requirement already satisfied: TextBlob in c:\programdata\anaconda3\envs\env\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from TextBlob) (3.6.5)
# Requirement already satisfied: click in c:\programdata\anaconda3\envs\env\lib\site-packages (from nltk>=3.1->TextBlob) (8.0.3)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\envs\env\lib\site-packages (from nltk>=3.1->TextBlob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\envs\env\lib\site-packages (from nltk>=3.1->TextBlob) (2021.8.3)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\envs\env\lib\site-packages (from nltk>=3.1->TextBlob) (4.62.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\env\lib\site-packages (from click->nltk>=3.1->TextBlob) (0.4.4)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\env\lib\site-packages (from click->nltk>=3.1->TextBlob) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\env\lib\site-packages (from importlib-metadata->click->nltk>=3.1->TextBlob) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\programdata\anaconda3\envs\env\lib\site-packages (from importlib-metadata->click->nltk>=3.1->TextBlob) (3.10.0.2)

# %%
# Checking Text
ex1 = df['clean_tweet'].iloc[10]
get_sentiment(ex1)
# Out:
# {'polarity': 0.1, 'subjectivity': 0.7, 'sentiment': 1}

# %%
df['sentiment_results'] = df['clean_tweet'].apply(get_sentiment)

# %%
# preview sentiment result
df['sentiment_results']
# Out:
# 0        {'polarity': 0.55, 'subjectivity': 0.65, 'sent...
# 1        {'polarity': -0.03125, 'subjectivity': 0.4375,...
# 2        {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# 3        {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# 4        {'polarity': 0.4166666666666667, 'subjectivity...
#                                ...
# 23893    {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# 23894    {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# 23895    {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# 23896    {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# 23897    {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# Name: sentiment_results, Length: 23898, dtype: object

# %%
df = df.join(pd.json_normalize(df['sentiment_results']))

# %%
df.head()
# Out:
#                                                 text  \
# 0             Safe and effective. #OxfordAstraZeneca
# 1  The day after the #Moderna #COVID19Vaccine... ...
# 2  @syd_m39 Not a girl but part of the #Moderna c...
# 3  When we can get #moderna and #pfitzer Vaccine ...
# 4                        Officially a #Moderna gay ?
#
#                extracted_hashtags  \
# 0            [#OxfordAstraZeneca]
# 1  [#Moderna, #COVID19Vaccine...]
# 2                      [#Moderna]
# 3            [#moderna, #pfitzer]
# 4                      [#Moderna]
#
#                                          clean_tweet  \
# 0                                Safe and effective
# 1  The day after the My arm is a little sore and ...
# 2                   Not a girl but part of the club
# 3              When we can get and Vaccine in India
# 4                                  Officially a gay
#
#                                    sentiment_results  polarity  subjectivity  \
# 0  {'polarity': 0.55, 'subjectivity': 0.65, 'sent...  0.550000      0.650000
# 1  {'polarity': -0.03125, 'subjectivity': 0.4375,... -0.031250      0.437500
# 2  {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...  0.000000      0.000000
# 3  {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...  0.000000      0.000000
# 4  {'polarity': 0.4166666666666667, 'subjectivity...  0.416667      0.583333
#
#    sentiment
# 0          1
# 1         -1
# 2          0
# 3          0
# 4          1

# %%
df['sentiment'].value_counts()
# Out:
#  1    11702
# -1     7046
#  0     5150
# Name: sentiment, dtype: int64

# %%
# Graph for value count
df['sentiment'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Plot with seaborn
import seaborn as sns
sns.countplot(df['sentiment'])
# Out:
# <AxesSubplot:xlabel='sentiment', ylabel='count'>

# %%
# Extraction
positive_tweet = df[df['sentiment'] == 1]['clean_tweet']
neutral_tweet = df[df['sentiment'] == 0]['clean_tweet']
negative_tweet = df[df['sentiment'] == -1]['clean_tweet']

# %%
# Remove Stopwords and Convert to Tokens
positive_tweet_list = positive_tweet.apply(nfx.remove_stopwords).tolist()
negative_tweet_list = negative_tweet.apply(nfx.remove_stopwords).tolist()
neutral_tweet_list = neutral_tweet.apply(nfx.remove_stopwords).tolist()

# %%
pos_tokens = [token for line in positive_tweet_list  for token in line.split()]
neg_tokens = [token for line in negative_tweet_list  for token in line.split()]
neut_tokens = [token for line in neutral_tweet_list  for token in line.split()]

# %%
# Get Tokens
def get_tokens(docx,num=30):
    word_tokens = Counter(docx)
    most_common = word_tokens.most_common(num)
    result = dict(most_common)
    return result

# %%
from collections import Counter
# Positive tokens
get_tokens(pos_tokens)
# Out:
# {'vaccine': 5061,
#  'new': 3058,
#  'vaccination': 2386,
#  'people': 1907,
#  'cases': 1851,
#  'know': 1743,
#  'amp': 1413,
#  'GMT]': 1300,
#  'deaths': 1258,
#  'COVID19': 1235,
#  'don’t': 1196,
#  'like': 1096,
#  'military': 878,
#  'good': 864,
#  'vaccinated': 822,
#  'think': 781,
#  'going': 781,
#  'got': 762,
#  'It’s': 631,
#  'I’m': 609,
#  '3': 595,
#  'kids': 579,
#  'COVID': 569,
#  'died': 565,
#  'told': 564,
#  'point': 549,
#  'says': 524,
#  'proof': 522,
#  'testicles': 511,
#  'fighting': 510}

# %%
# Fetching the tokens for all sentiments
most_common_pos_words = get_tokens(pos_tokens)
most_common_neg_words = get_tokens(neg_tokens)
most_common_neut_words = get_tokens(neut_tokens)

# %%
# Plot with seaborn
neg_df = pd.DataFrame(most_common_neg_words.items(),columns=['words','scores'])
neg_df.head()
# Out:
#          words  scores
# 0      vaccine    2631
# 1  vaccination    2059
# 2        COVID    1494
# 3          amp    1338
# 4        proof    1191

# %%
# Word Cloud
def plot_wordcloud(docx):
    plt.figure(figsize=(20,10))
    mywordcloud = WordCloud().generate(docx)
    plt.imshow(mywordcloud,interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
pos_docx = ' '.join(pos_tokens)
neg_docx = ' '.join(neg_tokens)
neu_docx = ' '.join(neut_tokens)

# %%
# Plotting wordcloud of positive words
import matplotlib.pyplot as plt
from wordcloud import WordCloud
plot_wordcloud(pos_docx)

# %%
# Wordcloud of negative words
plot_wordcloud(neg_docx)

# %%
# Wordcloud of neutral words
plot_wordcloud(neu_docx)

# %%
# text clean
def basic_clean(text):
    wnl = nltk.stem.WordNetLemmatizer()
    #remove stopwords
    stopwords = nltk.corpus.stopwords.words('english') #+ ADDITIONAL_STOPWORDS
    #removing non-ASCII characters,normalization, encoding/decoding, lower casing, and lemmatization.
    text = (unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore').lower())
    # Remove mentions
    text = re.sub(r'@[A-Za-z0-9_]+', '', text)
    # Remove hashtags
    text = re.sub(r'#', '', text)
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    text = url_pattern.sub(r'', text)
    text = re.sub('[0-9]+', '', text)
    words = re.sub(r'[^\w\s]', '', text).split()
    text = [wnl.lemmatize(word) for word in words if word not in stopwords]
    return text

# %%
import nltk 
import re
import unicodedata
tweet_cln = basic_clean(''.join(str(df['text'].tolist())))
tweet_cln
# Out:
# ['safe',
#  'effective',
#  'oxfordastrazeneca',
#  'day',
#  'moderna',
#  'covidvaccine',
#  'arm',
#  'little',
#  'sore',
#  'little',
#  'fatigued',
#  'usual',
#  'grandparent',
#  'noticeable',
#  'effect',
#  'though',
#  'girl',
#  'part',
#  'moderna',
#  'club',
#  'get',
#  'moderna',
#  'pfitzer',
#  'vaccine',
#  'india',
#  'officially',
#  'moderna',
#  'gay',
#  'got',
#  'pfizerbiontech',
#  'vaccine',
#  'sputnikv',
#  'efficiency',
#  'far',
#  'ahead',
#  'covishield',
#  'covaxin',
#  'one',
#  'go',
#  'firstdosedone',
#  'moderna',
#  'thankful',
#  'got',
#  'second',
#  'dose',
#  'moderna',
#  'vaccine',
#  'yesterday',
#  'far',
#  'side',
#  'effect',
#  'pretty',
#  'bad',
#  'manageable',
#  'soreness',
#  'injected',
#  'arm',
#  'got',
#  'nd',
#  'moderna',
#  'shot',
#  'mom',
#  'amp',
#  'grandma',
#  'got',
#  'johnsonandjohnson',
#  'amp',
#  'pfizer',
#  'deathly',
#  'allergy',
#  'zero',
#  'allergic',
#  'adverse',
#  'reaction',
#  'dont',
#  'let',
#  'allergy',
#  'stop',
#  'getting',
#  'covidvaccine',
#  'especially',
#  'lack',
#  'data',
#  'johnsonandjohnson',
#  'vaccine',
#  'efficacy',
#  'specifically',
#  'b',
#  'variant',
#  'fueling',
#  'current',
#  'surge',
#  'precedent',
#  'granting',
#  'eua',
#  'final',
#  'data',
#  'phase',
#  'available',
#  'sputnikv',
#  'covaxin',
#  'got',
#  'first',
#  'dose',
#  'moderna',
#  'vaccine',
#  'im',
#  'sure',
#  'working',
#  'jeff',
#  'bezos',
#  'hasnt',
#  'sent',
#  'check',
#  'thing',
#  'sarcasm',
#  'getvaccinated',
#  'moderna',
#  'covidvaccine',
#  'let',
#  'u',
#  'change',
#  'goal',
#  'post',
#  'related',
#  'cong',
#  'mmsyes',
#  'like',
#  'covaxin',
#  'given',
#  'emergency',
#  'approval',
#  'sputnikv',
#  'maybe',
#  'others',
#  'allowed',
#  'people',
#  'pay',
#  'get',
#  'vaccinated',
#  'vaccine',
#  'choice',
#  'sputnikv',
#  'get',
#  'approval',
#  'within',
#  'day',
#  'suggestion',
#  'fast',
#  'tracking',
#  'approval',
#  'vaccine',
#  'per',
#  'normsafter',
#  'mocking',
#  'modi',
#  'govt',
#  'exactly',
#  'suggestedresignation',
#  'prasad',
#  'apologise',
#  'resign',
#  'got',
#  'first',
#  'vaccine',
#  'moderna',
#  'mahalo',
#  'running',
#  'smooth',
#  'clinic',
#  'kona',
#  'covidvaccine',
#  'starting',
#  'today',
#  'new',
#  'chapter',
#  'begin',
#  'hospital',
#  'filled',
#  'hope',
#  'end',
#  'dark',
#  'covid',
#  'time',
#  'amp',
#  'joy',
#  'celebrating',
#  'lifecovidvaccine',
#  'pfizerbiontech',
#  'mrnavaccine',
#  'covidends',
#  'researcher',
#  'said',
#  'risk',
#  'cerebral',
#  'venous',
#  'thrombosis',
#  'covid',
#  'approximately',
#  'time',
#  'higher',
#  'compared',
#  'messenger',
#  'rna',
#  'vaccine',
#  'time',
#  'higher',
#  'compared',
#  'oxfordastrazeneca',
#  'vaccine',
#  'guy',
#  'got',
#  'first',
#  'dose',
#  'moderna',
#  'vaccine',
#  'today',
#  'halfway',
#  'closer',
#  'getting',
#  'back',
#  'lawrence',
#  'moderna',
#  'sleeveupjoco',
#  'astrazenica',
#  'substantially',
#  'lower',
#  'efficacy',
#  'pfizer',
#  'moderna',
#  'blood',
#  'clot',
#  'death',
#  'rare',
#  'across',
#  'age',
#  'group',
#  'vaccinated',
#  'including',
#  'aged',
#  'astrazeneca',
#  'vaccine',
#  'causing',
#  'blood',
#  'clot',
#  'nonsense',
#  'mother',
#  'shot',
#  'two',
#  'week',
#  'ago',
#  'got',
#  'headache',
#  'fatigue',
#  'right',
#  'rein',
#  'covidvaccine',
#  'oxfordastrazeneca',
#  'modi',
#  'government',
#  'go',
#  'ahead',
#  'production',
#  'covaxin',
#  'maharashtra',
#  'govt',
#  'bharatbiotech',
#  'vaccine',
#  'said',
#  'company',
#  'produce',
#  'also',
#  'take',
#  'time',
#  'news',
#  'got',
#  'first',
#  'dose',
#  'modern',
#  'covid',
#  'vaccination',
#  'tiny',
#  'needle',
#  'didnt',
#  'feel',
#  'thing',
#  'im',
#  'feeling',
#  'absolutely',
#  'fine',
#  'afterwardstake',
#  'evil',
#  'little',
#  'bastardmoderna',
#  'covidvaccine',
#  'govt',
#  'pushed',
#  'corner',
#  'ban',
#  'russian',
#  'sputnikv',
#  'vaccine',
#  'ke',
#  'amp',
#  'accept',
#  'uk',
#  'astrazenaca',
#  'little',
#  'know',
#  'master',
#  'issue',
#  'threat',
#  'ke',
#  'allow',
#  'vaccine',
#  'sold',
#  'ke',
#  'amp',
#  'end',
#  'colonial',
#  'monopoly',
#  'uk',
#  'kenyavsuk',
#  'nanyuki',
#  'kibaki',
#  'fwiw',
#  'ill',
#  'go',
#  'shot',
#  'either',
#  'pfizer',
#  'moderna',
#  'jampj',
#  'isnt',
#  'effective',
#  'one',
#  'shot',
#  'better',
#  'efficacy',
#  'worth',
#  'go',
#  'two',
#  'round',
#  'shot',
#  'covidvaccine',
#  'got',
#  'first',
#  'moderna',
#  'shot',
#  'yesterday',
#  'ask',
#  'went',
#  'moderna',
#  'vaccine',
#  'pakistan',
#  'using',
#  'sinopharm',
#  'processafter',
#  'st',
#  'dose',
#  'person',
#  'wait',
#  'day',
#  'get',
#  'nd',
#  'dose',
#  'nd',
#  'dose',
#  'wait',
#  'day',
#  'vaccine',
#  'make',
#  'antibodiesperson',
#  'get',
#  'covid',
#  'even',
#  'vaccination',
#  'vaccination',
#  'mean',
#  'get',
#  'coronavirus',
#  'perhaps',
#  'trial',
#  'run',
#  'new',
#  'ranger',
#  'regt',
#  'tier',
#  'recover',
#  'million',
#  'dos',
#  'oxfordastrazeneca',
#  'update',
#  'sputnikcoronavirus',
#  'coronavirusvaccine',
#  'sputnikv',
#  'two',
#  'day',
#  'tylenol',
#  'later',
#  'feeling',
#  'much',
#  'better',
#  'today',
#  'moderna',
#  'got',
#  'first',
#  'dose',
#  'moderna',
#  'vaccine',
#  'india',
#  'defense',
#  'budget',
#  'billion',
#  'pakistan',
#  'budget',
#  'billion',
#  'enemy',
#  'stronger',
#  'teach',
#  'child',
#  'weapon',
#  'missile',
#  'useless',
#  'let',
#  'kill',
#  'enemy',
#  'slingshotthink',
#  'wisely',
#  'everything',
#  'happen',
#  'existsinopharm',
#  'g',
#  'enabled',
#  'bobcatbeep',
#  'booppfizerbiontech',
#  'sure',
#  'bc',
#  'darpa',
#  'funding',
#  'development',
#  'implantable',
#  'biochipthe',
#  'chip',
#  'able',
#  'deploy',
#  'experimental',
#  'new',
#  'vaccine',
#  'developed',
#  'jointly',
#  'moderna',
#  'u',
#  'govt',
#  'could',
#  'change',
#  'human',
#  'dna',
#  'able',
#  'reprogramxamrna',
#  'aka',
#  'messenger',
#  'ribonucleic',
#  'acid',
#  'strange',
#  'mine',
#  'morning',
#  'oxfordastrazeneca',
#  'jab',
#  'apart',
#  'slightly',
#  'sore',
#  'arm',
#  'im',
#  'feeling',
#  'fine',
#  'sick',
#  'day',
#  'nd',
#  'shot',
#  'moderna',
#  'shot',
#  'fever',
#  'body',
#  'ache',
#  'headache',
#  'whole',
#  'body',
#  'sore',
#  'mom',
#  'finally',
#  'got',
#  'nd',
#  'dose',
#  'sinopharm',
#  'vaccine',
#  'vaccination',
#  'process',
#  'complete',
#  'shell',
#  'quarantine',
#  'another',
#  'week',
#  'develop',
#  'lifetime',
#  'antibody',
#  'side',
#  'effect',
#  'far',
#  'get',
#  'vaccinated',
#  'follow',
#  'sop',
#  'thank',
#  'china',
#  'covidvaccine',
#  'covid_',
#  'pakistan',
#  'buckle',
#  'buttercup',
#  'second',
#  'pfizerbiontech',
#  'dose',
#  'bear',
#  'misgiving',
#  'mild',
#  'side',
#  'effect',
#  'first',
#  'dose',
#  'alleviated',
#  'sure',
#  'beat',
#  'real',
#  'thing',
#  'though',
#  'covid',
#  'opposition',
#  'raise',
#  'issue',
#  'voice',
#  'heard',
#  'sindh',
#  'also',
#  'importing',
#  'sputnikv',
#  'chinese',
#  'vaccine',
#  'given',
#  'free',
#  'better',
#  'idea',
#  'plz',
#  'speak',
#  'plan',
#  'along',
#  'gate',
#  'eugenicsworldeconomicforum',
#  'klausschwab',
#  'cdc',
#  'nih',
#  'niaid',
#  'fauci',
#  'bigpharma',
#  'moderna',
#  'covid',
#  'covid',
#  'covidvaccine',
#  'covaxin',
#  'generally',
#  'medicine',
#  'used',
#  'cure',
#  'illness',
#  'first',
#  'time',
#  'used',
#  'get',
#  'vote',
#  'name',
#  'breakingbig',
#  'vaccine',
#  'updateafter',
#  'approving',
#  'sputnikv',
#  'foreign',
#  'vaccine',
#  'lively',
#  'given',
#  'emergency',
#  'use',
#  'authorization',
#  'indiagovt',
#  'looking',
#  'expand',
#  'basket',
#  'vaccine',
#  'order',
#  'ramp',
#  'vaccinationdrivenvaccineshortage',
#  'vaccinateeveryindian',
#  'ok',
#  'feeling',
#  'arm',
#  'soreness',
#  'today',
#  'bad',
#  'still',
#  'feel',
#  'tired',
#  'normal',
#  'dealing',
#  'nasal',
#  'issue',
#  'think',
#  'thats',
#  'due',
#  'allergy',
#  'anything',
#  'awful',
#  'noticeable',
#  'hoping',
#  'second',
#  'one',
#  'easier',
#  'moderna',
#  'article',
#  'hugely',
#  'boosted',
#  'sputnikv',
#  'vaccine',
#  'image',
#  'eu',
#  'already',
#  'witnessing',
#  'race',
#  'procure',
#  'approved',
#  'ema',
#  'produce',
#  'well',
#  'germany',
#  'austria',
#  'slovakia',
#  'shown',
#  'interest',
#  'domestically',
#  'producing',
#  'russia',
#  'got',
#  'second',
#  'moderna',
#  'vaccine',
#  'yesterday',
#  'feeling',
#  'like',
#  'got',
#  'run',
#  'truck',
#  'today',
#  'however',
#  'im',
#  'grateful',
#  'worthit',
#  'fullyvaccinated',
#  'thankful',
#  'ok',
#  'got',
#  'sick',
#  'second',
#  'injection',
#  'happen',
#  'moderna',
#  'phizer',
#  'jabtobeatcorona',
#  'vaccine',
#  'got',
#  'first',
#  'dose',
#  'pfizerbiontech',
#  'covid',
#  'coronavirusvaccine',
#  'yesterday',
#  'side',
#  'effect',
#  'last',
#  'hour',
#  'slightly',
#  'achy',
#  'arm',
#  'antibody',
#  'test',
#  'day',
#  'showed',
#  'zero',
#  'antisarscov',
#  'antibody',
#  'let',
#  'see',
#  'many',
#  'week',
#  'dr',
#  'daniel',
#  'chirundu',
#  'said',
#  'took',
#  'sinopharm',
#  'vaccine',
#  'protect',
#  'work',
#  'client',
#  'vaccination',
#  'also',
#  'served',
#  'cue',
#  'action',
#  'among',
#  'subordinate',
#  'others',
#  'demanding',
#  'slept',
#  'pretty',
#  'much',
#  'two',
#  'day',
#  'covidvaccine',
#  'thought',
#  'id',
#  'resync',
#  'body',
#  'clock',
#  'staying',
#  'night',
#  'hour',
#  'zacksnydersjusticeleague',
#  'seeing',
#  'trailer',
#  'riverhunters',
#  'ive',
#  'watched',
#  'entire',
#  'first',
#  'series',
#  'oxfordastrazeneca',
#  'british',
#  'jab',
#  'british',
#  'people',
#  'oxfordastrazeneca',
#  'okay',
#  'made',
#  'belgium',
#  'say',
#  'oxford',
#  'title',
#  'dammit',
#  'pregnant',
#  'person',
#  'getting',
#  'moderna',
#  'covidvaccine',
#  'today',
#  'anyone',
#  'know',
#  'official',
#  'study',
#  'enter',
#  'covid',
#  'covid',
#  'coronavirus',
#  'coronavaccine',
#  'getting',
#  'moderna',
#  'vax',
#  'today',
#  'worried',
#  'side',
#  'effect',
#  'excited',
#  'part',
#  'stop',
#  'damn',
#  'spread',
#  'covid',
#  'january',
#  'recommend',
#  'despite',
#  'highest',
#  'recovery',
#  'rate',
#  'rest',
#  'world',
#  'vaccine',
#  'covishield',
#  'covaxin',
#  'invented',
#  'administerd',
#  'war',
#  'footing',
#  'much',
#  'fanfare',
#  'situation',
#  'still',
#  'alarmingmeans',
#  'vaccine',
#  'efficacious',
#  'contain',
#  'coronavirus',
#  'drama',
#  'pacify',
#  'outcry',
#  'nd',
#  'moderna',
#  'shot',
#  'yesterday',
#  'today',
#  'anticipation',
#  'possible',
#  'negative',
#  'side',
#  'effect',
#  'decided',
#  'sending',
#  'k',
#  'daycare',
#  'good',
#  'idea',
#  'dh',
#  'made',
#  'feel',
#  'guilty',
#  'sending',
#  'dont',
#  'know',
#  'mean',
#  'ugh',
#  'im',
#  'going',
#  'back',
#  'bed',
#  'bahrain',
#  'ministry',
#  'health',
#  'receives',
#  'dos',
#  'chinese',
#  'covid',
#  'sinopharm',
#  'vaccine',
#  'jakarta',
#  'siti',
#  'nadia',
#  'tarmizi',
#  'spokesperson',
#  'indonesia',
#  'covid',
#  'vaccine',
#  'programme',
#  'said',
#  'found',
#  'chinese',
#  'vaccine',
#  'met',
#  'requirement',
#  'effective',
#  'noted',
#  'clinical',
#  'trial',
#  'sinovac',
#  'indonesia',
#  'showed',
#  'effective',
#  'speakupforvaccinesforall',
#  'people',
#  'want',
#  'covaxin',
#  'demand',
#  'amitshah',
#  'modi',
#  'rally',
#  'coronavirus',
#  'covid',
#  'every',
#  'time',
#  'read',
#  'story',
#  'im',
#  'tempted',
#  'ask',
#  'vote',
#  'kisko',
#  'diya',
#  'tha',
#  'know',
#  'mean',
#  'okay',
#  'mean',
#  'newindia',
#  'pertinent',
#  'question',
#  'imo',
#  'covid',
#  'covid',
#  'covaxin',
#  'actually',
#  'french',
#  'done',
#  'acknowledge',
#  'vaccine',
#  'wouldnt',
#  'ready',
#  'end',
#  'turned',
#  'facility',
#  'production',
#  'pfizerbiontech',
#  'vaccine',
#  'despite',
#  'india',
#  'brink',
#  'severe',
#  'second',
#  'wave',
#  'even',
#  'consider',
#  'covidvaccine',
#  'none',
#  'trustworthy',
#  'yet',
#  'would',
#  'definitely',
#  'taken',
#  'one',
#  'genuine',
#  'chinavirus',
#  'chinesevirus',
#  'chinesebioterrorism',
#  'ccpvirus',
#  'covaxin',
#  'covidshield',
#  'bet',
#  'scientist',
#  'created',
#  'vaccine',
#  'male',
#  'forgot',
#  'almost',
#  'woman',
#  'breast',
#  'armpit',
#  'lymph',
#  'node',
#  'ovary',
#  'uterus',
#  'birth',
#  'control',
#  'period',
#  'single',
#  'thought',
#  'woman',
#  'pathetic',
#  'wake',
#  'gentleman',
#  'johnsonandjohnson',
#  'pfizer',
#  'moderna',
#  'first',
#  'dose',
#  'moderna',
#  'covid',
#  'vaccine',
#  'done',
#  'feel',
#  'fine',
#  'far',
#  'moderna',
#  'covidvaccine',
#  'covid',
#  'going',
#  'moderna',
#  'todaycovidvaccinefastenseatbeltsraiseseatstouprightpositionstoretraytables',
#  'wheres',
#  'sputnikv',
#  'successrate',
#  'pfizer',
#  'death',
#  'second',
#  'dose',
#  'moderna',
#  'kicking',
#  'as',
#  'arm',
#  'hurt',
#  'like',
#  'hell',
#  'fever',
#  'sweat',
#  'headache',
#  'teeth',
#  'pain',
#  ...]

# %%
#top 30 unigram
unigram =(pd.Series(nltk.ngrams(tweet_cln , 1)).value_counts())[:30]
unigram
# Out:
# (vaccine,)                12343
# (covid,)                  11102
# (vaccination,)             6586
# (new,)                     3492
# (people,)                  3417
# (amp,)                     3031
# (case,)                    2948
# (get,)                     2921
# (coronavirus,)             2717
# (know,)                    2713
# (like,)                    2494
# (think,)                   2420
# (dont,)                    2361
# (one,)                     2359
# (death,)                   2265
# (proof,)                   2107
# (vaccinated,)              2049
# (every,)                   1836
# (news,)                    1773
# (would,)                   1741
# (breaking,)                1738
# (u,)                       1637
# (im,)                      1572
# (rt,)                      1548
# (got,)                     1546
# (coronaviruspandemic,)     1394
# (gmt,)                     1310
# (coronavirusupdate,)       1304
# (requiring,)               1269
# (time,)                    1258
# dtype: int64

# %%
#Top 20 Bigrams
bigram =(pd.Series(nltk.ngrams(tweet_cln , 2)).value_counts())[:20]
bigram
# Out:
# (covid, vaccination)                1581
# (covid, vaccine)                    1543
# (breaking, news)                    1446
# (new, case)                         1366
# (covid, coronaviruspandemic)        1303
# (coronavirus, coronavirusupdate)    1300
# (coronavirusupdate, covid)          1300
# (gmt, coronavirus)                  1300
# (think, every)                      1257
# (rt, think)                         1255
# (coronaviruspandemic, new)          1191
# (proof, covid)                      1135
# (announces, begin)                  1124
# (begin, requiring)                  1124
# (requiring, proof)                  1112
# (los, angeles)                      1047
# (angeles, announces)                1038
# (news, los)                         1037
# (vaccination, bar)                  1037
# (bar, nightlife)                    1037
# dtype: int64

# %%
#Top 20 Trigrams
trigram =(pd.Series(nltk.ngrams(tweet_cln , 3)).value_counts())[:20]
trigram
# Out:
# (coronavirusupdate, covid, coronaviruspandemic)    1300
# (coronavirus, coronavirusupdate, covid)            1300
# (gmt, coronavirus, coronavirusupdate)              1300
# (rt, think, every)                                 1255
# (covid, coronaviruspandemic, new)                  1179
# (coronaviruspandemic, new, case)                   1167
# (proof, covid, vaccination)                        1130
# (announces, begin, requiring)                      1124
# (los, angeles, announces)                          1038
# (covid, vaccination, bar)                          1037
# (vaccination, bar, nightlife)                      1037
# (requiring, proof, covid)                          1037
# (begin, requiring, proof)                          1037
# (every, city, america)                             1037
# (angeles, announces, begin)                        1037
# (breaking, news, los)                              1037
# (bar, nightlife, destination)                      1037
# (nightlife, destination, rt)                       1037
# (destination, rt, think)                           1037
# (think, every, city)                               1037
# dtype: int64

# %%
#Plot Unigram
unigram.sort_values().plot.barh(color='brown', width=.9, figsize=(12, 8))
plt.title('30 Most Frequently Occuring Unigrams')
plt.ylabel('Unigram')
plt.xlabel('No. of Occurances')
# Out:
# Text(0.5, 0, 'No. of Occurances')

# %%
#plot bigram
bigram.sort_values().plot.barh(color='orange', width=.9, figsize=(12, 8))
plt.title('20 Most Frequently Occuring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('No. of Occurances')
# Out:
# Text(0.5, 0, 'No. of Occurances')

# %%
#plot trigram 
trigram.sort_values().plot.barh(color='blue', width=.9, figsize=(12, 8))
plt.title('20 Most Frequently Occuring Trigrams')
plt.ylabel('Trigram')
plt.xlabel('No. of Occurances')
# Out:
# Text(0.5, 0, 'No. of Occurances')

# %%
dataset=df[['clean_tweet','sentiment']]
label=dataset[['sentiment']]

# %%
label.dtypes
# Out:
# sentiment    int64
# dtype: object

# %%
text = dataset['clean_tweet'].values.tolist()

# %%
dataset.reset_index(inplace=True, drop=True)
dataset.head()
# Out:
#                                          clean_tweet  sentiment
# 0                                Safe and effective           1
# 1  The day after the My arm is a little sore and ...         -1
# 2                   Not a girl but part of the club           0
# 3              When we can get and Vaccine in India           0
# 4                                  Officially a gay           1

# %%
#classifying Depressive and Non depressive labels
label = []
for i in range(len(dataset)):
    lbls = dataset['sentiment'][i]
    if lbls == 1:
        lbl = 'positive'
    elif lbls==0:
        lbl = 'Neutral'
    else :
        lbl='negative'
    
    
    label.append(lbl)

# %%
sns.countplot(label)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# Main text
text = np.array(text)

# %%
# Corresponding labels
label=np.array(dataset['sentiment'])

# %%
# Label Encoding
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder().fit_transform(label)

# %%
set(label)
# Out:
# {0, 1, 2}

# %% [markdown]
# ## Support Vector Machine

# %% [markdown]
# Ngrams(1,2)-features = All

# %%
# Splitting into training and testing
X_train, X_test, y_train, y_test = train_test_split(text,label,stratify=label, random_state=32)

# %%
X_train.shape, X_test.shape
# Out:
# ((17923,), (5975,))

# %%
# Applying Count Vectorizer
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, stop_words='english', ngram_range=(1,2))

X_train = bow_vectorizer.fit_transform(X_train)
X_test = bow_vectorizer.transform(X_test)

# %%
# SVM Classifier
svm_clf = svm.SVC(kernel='linear')

# Fitting the model
svm_clf.fit(X_train, y_train)

# Prediction
prediction=svm_clf.predict(X_test)

# Accuracy
acc = accuracy_score(y_test, prediction)
sensitivity = sensitivity_score(y_test, prediction, average='macro')
specificity = specificity_score(y_test, prediction, average='macro')
print('Accuracy score: ', acc)
print('Sensitivity score: ', sensitivity)
print('Specificity score: ', specificity)
# Out:
# Accuracy score:  0.8707949790794979
# Sensitivity score:  0.8655002678540523
# Specificity score:  0.9325257438586873

# %%
# Confusion Matrics
metrics.plot_confusion_matrix(svm_clf, X_test, y_test)

# %%
# Confusion Matrix
print(confusion_matrix(y_test, prediction))
# Out:
# [[1475  114  173]
#  [  63 1115  109]
#  [ 162  151 2613]]

# %%
# Classification Report
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85      1762
#            1       0.81      0.87      0.84      1287
#            2       0.90      0.89      0.90      2926
#
#     accuracy                           0.87      5975
#    macro avg       0.86      0.87      0.86      5975
# weighted avg       0.87      0.87      0.87      5975

# %% [markdown]
# Ngrams(1,2)-features = 2000

# %%
#splitting into training and testing

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(text,label,stratify=label, random_state=16)

# Applying Count Vectorizer
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=2000, stop_words='english', ngram_range=(1,2))

X_train = bow_vectorizer.fit_transform(X_train)
X_test = bow_vectorizer.transform(X_test)

# SVM Classifier
svm_clf = svm.SVC(kernel='linear')

# Fitting the model
svm_clf.fit(X_train, y_train)

# Prediction
prediction=svm_clf.predict(X_test)

# Accuracy
acc = accuracy_score(y_test, prediction)
sensitivity = sensitivity_score(y_test, prediction, average='macro')
specificity = specificity_score(y_test, prediction, average='macro')
print('Accuracy score: ', acc)
print('Sensitivity score: ', sensitivity)
print('Specificity score: ', specificity)
# Out:
# Accuracy score:  0.8403347280334728
# Sensitivity score:  0.8367964320231481
# Specificity score:  0.9181902988374416

# %%
# Confusion Matrics
metrics.plot_confusion_matrix(svm_clf, X_test, y_test)

# %%
# Confusion Matrix
print(confusion_matrix(y_test, prediction))
# Out:
# [[1425  152  185]
#  [  78 1086  123]
#  [ 197  219 2510]]

# %%
# Classification Report
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82      1762
#            1       0.75      0.84      0.79      1287
#            2       0.89      0.86      0.87      2926
#
#     accuracy                           0.84      5975
#    macro avg       0.82      0.84      0.83      5975
# weighted avg       0.84      0.84      0.84      5975

# %% [markdown]
# ## Random Forest

# %% [markdown]
# Ngrams(1,1)-features = All

# %%
# Splitting data into training and testing
X_train, X_test, y_train, y_test = train_test_split(text,label,stratify=label, random_state=2)

# feature extraction
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, stop_words='english', ngram_range=(1,1))

X_train = bow_vectorizer.fit_transform(X_train)
X_test = bow_vectorizer.transform(X_test)

# Random Forest classifier
rf_clf = RandomForestClassifier()

# Fitting the model
rf_clf.fit(X_train, y_train)

# Prediction
prediction=rf_clf.predict(X_test)

# Accuracy
acc = accuracy_score(y_test, prediction)
sensitivity = sensitivity_score(y_test, prediction, average='macro')
specificity = specificity_score(y_test, prediction, average='macro')
print('Accuracy score: ', acc)
print('Sensitivity score: ', sensitivity)
print('Specificity score: ', specificity)
# Out:
# Accuracy score:  0.8826778242677824
# Sensitivity score:  0.8787562997790609
# Specificity score:  0.9371410662251743

# %%
# Confusion Matrics
metrics.plot_confusion_matrix(rf_clf, X_test, y_test)

# %%
# Confusion Matrix
print(confusion_matrix(y_test, prediction))
# Out:
# [[1428  112  222]
#  [   9 1175  103]
#  [  65  190 2671]]

# %%
# Classification Report
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.88      1762
#            1       0.80      0.91      0.85      1287
#            2       0.89      0.91      0.90      2926
#
#     accuracy                           0.88      5975
#    macro avg       0.88      0.88      0.88      5975
# weighted avg       0.89      0.88      0.88      5975

# %% [markdown]
# Ngrams(1,2)-features = 2000

# %%
# Splitting data into training and testing
X_train, X_test, y_train, y_test = train_test_split(text,label,stratify=label, random_state=3)

# feature extraction
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=2000, stop_words='english', ngram_range=(1,2))

X_train = bow_vectorizer.fit_transform(X_train)
X_test = bow_vectorizer.transform(X_test)

# Random Forest classifier
rf_clf = RandomForestClassifier()

# Fitting the model
rf_clf.fit(X_train, y_train)

# Prediction
prediction=rf_clf.predict(X_test)

# Accuracy
acc = accuracy_score(y_test, prediction)
sensitivity = sensitivity_score(y_test, prediction, average='macro')
specificity = specificity_score(y_test, prediction, average='macro')
print('Accuracy score: ', acc)
print('Sensitivity score: ', sensitivity)
print('Specificity score: ', specificity)
# Out:
# Accuracy score:  0.8649372384937238
# Sensitivity score:  0.8572877174048092
# Specificity score:  0.9281386294123161

# %%
# Confusion Matrics
metrics.plot_confusion_matrix(rf_clf, X_test, y_test)

# %%
# Confusion Matrix
print(confusion_matrix(y_test, prediction))
# Out:
# [[1415  134  213]
#  [  27 1117  143]
#  [  82  208 2636]]

# %%
# Classification Report
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1762
#            1       0.77      0.87      0.81      1287
#            2       0.88      0.90      0.89      2926
#
#     accuracy                           0.86      5975
#    macro avg       0.86      0.86      0.86      5975
# weighted avg       0.87      0.86      0.87      5975

# %% [markdown]
# ##Bert

# %%
# Bert Requirement
import os
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID";
os.environ["CUDA_VISIBLE_DEVICES"] = "0";

# %%
# Splitting Function
def split_data(review_text, review_label):
  train_ratio = 0.80
  test_ratio = 0.20
  X_train, X_test, y_train, y_test = train_test_split(review_text, review_label, test_size=test_ratio, stratify=review_label, random_state=100)
  return X_train, X_test, y_train, y_test

# Bert Implementation
def DistilBert(X,y):

  X_train, X_test, y_train, y_test = split_data(X, y)
  model_used = 'distilbert-base-uncased'
  from ktrain import text
 
  transformer = text.Transformer(model_name=model_used, maxlen=512, class_names=['Positive', 'Negative', 'Neutral'])

  train_data = transformer.preprocess_train(X_train, y_train)
  test_data = transformer.preprocess_test(X_test, y_test)

  model = transformer.get_classifier()

  learner = ktrain.get_learner(model, train_data=train_data, val_data = test_data, batch_size=16)
  return learner

# %%
# Equating
positive_tweet_list == negative_tweet_list == neutral_tweet_list
# Out:
# False

# %%
# Seperating the sentiments
sentiment_neg = list(np.ones(len(negative_tweet_list),dtype=int)*2)
sentiment_pos = list(np.ones(len(positive_tweet_list),dtype=int))
sentiment_neu = list(np.ones(len(neutral_tweet_list),dtype=int)*0)

# %%
# Data in desirable format
df_text = positive_tweet_list+negative_tweet_list+neutral_tweet_list
df_labels = sentiment_pos+sentiment_neg+sentiment_neu

# %%
# !pip3 install ktrain==0.28.2 --user
# Out:
# Requirement already satisfied: ktrain==0.28.2 in c:\users\administrator\appdata\roaming\python\python37\site-packages (0.28.2)
# Requirement already satisfied: langdetect in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (1.0.9)
# Requirement already satisfied: chardet in c:\users\administrator\appdata\roaming\python\python37\site-packages (from ktrain==0.28.2) (4.0.0)
# Requirement already satisfied: fastprogress>=0.1.21 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (1.0.0)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (1.1.0)
# Requirement already satisfied: whoosh in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (2.7.4)
# Requirement already satisfied: scikit-learn==0.23.2 in c:\users\administrator\appdata\roaming\python\python37\site-packages (from ktrain==0.28.2) (0.23.2)
# Requirement already satisfied: seqeval==0.0.19 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (0.0.19)
# Requirement already satisfied: jieba in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (0.42.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (21.3)
# Requirement already satisfied: keras-bert>=0.86.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (0.88.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (2.26.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (3.5.1)
# Requirement already satisfied: cchardet in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (2.1.7)
# Requirement already satisfied: transformers<=4.10.3,>=4.0.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (4.10.3)
# Requirement already satisfied: sentencepiece in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (0.1.96)
# Requirement already satisfied: syntok in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (1.3.2)
# Requirement already satisfied: pandas>=1.0.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from ktrain==0.28.2) (1.3.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from scikit-learn==0.23.2->ktrain==0.28.2) (3.0.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from scikit-learn==0.23.2->ktrain==0.28.2) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\envs\env\lib\site-packages (from scikit-learn==0.23.2->ktrain==0.28.2) (1.18.5)
# Requirement already satisfied: Keras>=2.2.4 in c:\programdata\anaconda3\envs\env\lib\site-packages (from seqeval==0.0.19->ktrain==0.28.2) (2.7.0)
# Requirement already satisfied: keras-transformer>=0.39.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-bert>=0.86.0->ktrain==0.28.2) (0.39.0)
# Requirement already satisfied: keras-pos-embd>=0.12.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain==0.28.2) (0.12.0)
# Requirement already satisfied: keras-multi-head>=0.28.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain==0.28.2) (0.28.0)
# Requirement already satisfied: keras-position-wise-feed-forward>=0.7.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain==0.28.2) (0.7.0)
# Requirement already satisfied: keras-embed-sim>=0.9.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain==0.28.2) (0.9.0)
# Requirement already satisfied: keras-layer-normalization>=0.15.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain==0.28.2) (0.15.0)
# Requirement already satisfied: keras-self-attention>=0.50.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from keras-multi-head>=0.28.0->keras-transformer>=0.39.0->keras-bert>=0.86.0->ktrain==0.28.2) (0.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain==0.28.2) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain==0.28.2) (4.28.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain==0.28.2) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain==0.28.2) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain==0.28.2) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\env\lib\site-packages (from matplotlib>=3.0.0->ktrain==0.28.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\env\lib\site-packages (from pandas>=1.0.1->ktrain==0.28.2) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->ktrain==0.28.2) (1.16.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (4.8.2)
# Requirement already satisfied: sacremoses in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (0.0.46)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (0.10.3)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (4.62.3)
# Requirement already satisfied: huggingface-hub>=0.0.12 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (0.2.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (3.4.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\envs\env\lib\site-packages (from transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (2021.8.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\envs\env\lib\site-packages (from huggingface-hub>=0.0.12->transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (3.10.0.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\env\lib\site-packages (from tqdm>=4.27->transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\env\lib\site-packages (from importlib-metadata->transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\env\lib\site-packages (from requests->ktrain==0.28.2) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\envs\env\lib\site-packages (from requests->ktrain==0.28.2) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\env\lib\site-packages (from requests->ktrain==0.28.2) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\env\lib\site-packages (from requests->ktrain==0.28.2) (3.3)
# Requirement already satisfied: click in c:\programdata\anaconda3\envs\env\lib\site-packages (from sacremoses->transformers<=4.10.3,>=4.0.0->ktrain==0.28.2) (8.0.3)

# %%
# Implementing bert
from ktrain import text
learner = DistilBert(df_text, df_labels)
# Out:
# preprocessing train...
# language: en
# train sequence lengths:
# 	mean : 16
# 	95percentile : 27
# 	99percentile : 32
# Is Multi-Label? False
# preprocessing test...
# language: en
# test sequence lengths:
# 	mean : 16
# 	95percentile : 27
# 	99percentile : 33

# %%
# Fitting the model
history = learner.fit(1e-4,1)
# Out:
# 1195/1195 [==============================] - 12681s 11s/step - loss: 0.4513 - accuracy: 0.8198 - val_loss: 0.3083 - val_accuracy: 0.8893

# %%
np.mean(history.history['accuracy'])
# Out:
# 0.8198032975196838
